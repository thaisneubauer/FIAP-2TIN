# %% [markdown]
# <img src="http://sonetodigital.com.br/adm/wp-content/uploads/2018/12/logo-fiap.png" width="150" align="left"/>
#
# <br/><br/>
#
# <font size=5 color="#ed145b"><b> Engenharia da Computação </b></font><font size=5 color="#ed145b"> - Inteligência Artificial e computacional </font>
#
# <font size=4 color="#ed145b"> Profa. Thais Rodrigues Neubauer - profthais.neubauer@fiap.com.br</font>

# %% [markdown]
# <font size=5 ><b>Aula 01</b></font>

# %% [markdown]
# ## O que é Inteligência Artificial
#
# Capacidade de solucionar problemas difíceis - O que é difícil?
#
# <img src="images/IA.png" align="left"/>
#
# <font size=1>(apud) Stuart J. Russell and Peter Norvig. 2003. Artificial Intelligence: A Modern Approach (2 ed.).Pearson Education.</font>

# %% [markdown]
# ## Inteligência Computacional
#
# - Um **ramo da Inteligência Artificial**.
# - Tem o objetivo de usar técnicas computacionais capazes de aprender, se adaptar e evoluir, para desenvolver softwares que possam ser considerados, em algum nível, inteligentes.
# - Técnicas de Inteligência Computacional que lidam com raciocínio:
#
#     - **indutivo**: redes neurais artificiais e máquinas de vetores de suporte (SVM).
#     - **aproximado**: lógica Fuzzy.
#     - **evolutivo**: algoritmos genéticos.
#
# <font size=1>IEEE Computational Intelligence Society – Montreal Chapter. 2008. Computational intelligence (CI) Definition. (2008). http://ewh.ieee.org/r7/montreal/cis/</font>
#
# <font size=1>Janos Abonyí, Balazs Feil, and Ajith Abraham. 2005. Computational intelligence in data mining. Informatica 29, 1 (2005), 3–12.</font>

# %% [markdown]
# ## Raciocínio
#
# Exercício da razão pelo qual se procura alcançar o entendimento de atos e fatos, formular ideias, elaborar juízos, deduzir algo a partir de uma ou mais premissas - Raciocínio inferencial.
#
# - Raciocínio dedutivo
# - Raciocínio indutivo
# - Raciocínio abdutivo

# %% [markdown]
# ### Raciocínio dedutivo (Silogismo) - universal para particular
#
# Conhece: p(a,b), p(a,d), p(b,c), p(d,e), p(d,g), p(e,f), p(X,Y) E p(Y,Z) --> a(X,Z)
#
# Conclui: a(a,c), a(a,e), a(a,g), a(d,f)
#
# ---
# *Todo homem é mortal.*
#
# *Aristóteles é um homem.*
#
# *Aristóteles é mortal.*
#
# ---

# %% [markdown]
# ### Raciocínio indutivo - particular pro universal
#
# Conhece: p(a,b), p(a,d), p(d,e), p(d,g), p(e,f)
#
# Observa: a(a,e), a(d,f)
#
# Aprende: p(X,Y) E p(Y,Z) --> a(X,Z)
#
# ---
#
# *O pardal é um pássaro que voa.*
#
# *A pomba é um pássaro que voa. *
#
# *O urubu é um pássaro que voa. *
#
# *Pardal, pomba e urubu são pássaros que vooam. *
#
# *Todo pássaro voa.*
#
# ---

# %% [markdown]
# ### Raciocínio abdutivo - particular pro universal para explicar (melhor hipótese)
#
# Conhece: p(a,b), p(a,d), p(b,c), p(d,e), p(d,g), p(e,f), p(X,Y) E p(Y,Z) --> a(X,Z)
#
# Observa: a(a,c)
#
# Explica: p(b,c) ou p(d,c)
#
# ---
#
# *Os telhados estão molhados.*
#
# *Logo, choveu.*
#
# ---
#
# *muito usado em investigações, detetives forenses, diagnósticos médicos

# %% [markdown]
# ## Aprendizado de máquina (*Machine learning*)
# - Abordagem de aprendizado para o desenvolvimento de software.
# - Não necessariamente um conjunto de técnicas!
# - Diferentes tipos de técnicas podem ser aplicadas em Aprendizado de máquina.
# - Pode incluir algumas técnicas de Inteligência Computacional.
#
# <font size=1>Tom M. Mitchell. 1997. Machine Learning (1st ed.).
#     McGraw Hill, New York, NY, USA.</font>
#
# <font size=1>Simon Haykin. 2009. Neural Networks and Learning Machines (3rd ed.).
# Pearson Education, NJ, USA. </font>

# %% [markdown]
# ## Aprendizado
#
# Passar a ter conhecimento sobre, passar a possuir habilidade técnica (em).
#
# Exemplo: aprender um novo idioma, aprender judô.
#
#
# <img src="images/superv_vs_notsupervis.jpg" width = 600 align="left"/>

# %% [markdown]
# ### Aprendizado supervisionado
# Processo de aproximação de uma função a partir de um conjunto de dados no qual os dados são descrito por atributos (valores de entrada em uma função) e estão relacionados a uma série de rótulos possíveis (valor de saída de uma função). Geralmente, um algoritmo usado para implementar esse processo itera sobre o conjunto de dados, ajustando alguns parâmetros que determinam a função requerida.
#
# ### Aprendizado não supervisionado
# Processo de descoberta de relacionamentos existentes entre os dados de um conjunto de dados, descritos por atributos descritivos. Geralmente, um algoritmo usado para implementar esse processo itera sobre o conjunto de dados analisando as similaridades entre os dados.

# %% [markdown]
# ## Teste de Turing
#
# - No artigo *Computing Machinery and Intelligence*, Turing discutiu as condições para considerar que uma máquina é inteligente.
# - Ele argumentou que se a máquina pudesse se passar por um humano mediante um observador inteligente, então certamente ela poderia ser considerada inteligente.
# - Este teste satisfaria a maioria das pessoas, mas não todos os filósofos.
# - Neste teste, o observador poderia interagir com a máquina e com um humano; o humano tentaria convencer o observador (que era também um humano) de que se tratava realmente de um humano, e a máquina tentaria enganar o observador.

# %% [markdown]
# ## Agentes
# - O livro Inteligência Artificial, de Stuart Russel e Peter Norvig é a principal referência para ensino de IA em nível de graduação.
# - Nesse livro, foi adotada uma abordagem baseada em **agentes**.
# - **Agente** é tudo que pode ser considerado capaz de perceber seu ambiente por meio de sensores e de agir sobre esse ambiente por meio de atuadores.
# - **Agentes racionais**: para cada sequência de percepções possível, um agente racional deve selecionar uma ação que se espera que maximize sua medida de desempenho, dada a evidência fornecida pela sequência de percepções e por qualquer conhecimento interno do agente.
#
#
# <font size=1>Russel, S; Norvig, P. Inteligência Artificial. Editora Campus, 2004.</font>

# %% [markdown]
# ## Introdução a Python
#
# Abra o nosso repositório no [Binder](https://mybinder.org/v2/gh/thaisneubauer/FIAP-3ECA-IA/master)

# %% [markdown]
# Duas das principais ferramentas para realizar manipular, tratar, sumarizar e visualizar dados em Python são **Numpy** e **Pandas**. São bibliotecas (conjuntos de classes, funções e objetos) feitos para análise de dados.
#
# Enquanto Numpy foca em manipulação de vetores e matrizes, muito úteis para realizar operações de álgebra linear (como decomposição de matrizes, calculo de similaridade e distâncias, etc), o Pandas é focado em dados tabulares e manipulações de dados estruturados.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Numpy e listas em Python

# %%
lista_de_ints = [1, 2, 3, 4]
lista_de_strings = ["um", "dois"]
lista_de_listas = [[1,2], [1,2,3,4]]
outra_lista = [5, 5, "banana", 8]

# %% [markdown]
# Listas são pouco indicadas para fazer contas.
#
# Suponha que tenhamos duas listas para gerênciar uma compra em uma loja: uma contendo a quantidade de itens, outra o valor dos ítens.

# %%
quantidades = [1, 10, 0, 5, 2]
precos = [10.5, 20.3, 100.75, 0.5, 2.0]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Exercício:</b>
# Calcule o preço total da compra do cliente, multiplicando a quantidade pedida do primeiro produto pelo seu preço, a quantidade pedida do segundo produto pelo seu preço e assim por diante.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Solução:</b>
# </div>

# %%
resultado = 0
for i in range(len(precos)):
    resultado += quantidades[i] * precos[i]
        
resultado
# Out:
# 220.0

# %% [markdown]
# Alternativamente, usando a função `sum` que soma todos os itens de uma lista:

# %%
sum([q * p for p, q in zip(quantidades, precos)])
# Out:
# 220.0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Não funciona:</b>
# </div>

# %%
#pagtos = quantidades * precos

# %% [markdown]
# Soma de listas é o mesmo que *concatenação* (listas padrão do Python)

# %%
quantidades + precos
# Out:
# [1, 10, 0, 5, 2, 10.5, 20.3, 100.75, 0.5, 2.0]

# %% [markdown]
# Com Numpy...

# %%
x = np.array([1, 2, 3])
y = np.array([5.2, 3.4, 1.0])
x + y
# Out:
# array([6.2, 5.4, 4. ])

# %%
x * y
# Out:
# array([5.2, 6.8, 3. ])

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Exercício:</b>
#
# Calcule o preço total da compra do cliente, multiplicando a quantidade pedida do primeiro produto pelo seu preço, a quantidade pedida do segundo produto pelo seu preço e assim por diante. Dessa vez, faça uso dos arrays do numpy.
# </div>

# %%
quantidades_np = np.array([1, 10, 0, 5, 2])
precos_np = np.array([10.5, 20.3, 100.75, 0.5, 2.0])

# %%
quantidades_np
# Out:
# array([ 1, 10,  0,  5,  2])

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Solução:</b>
# </div>

# %%
pagtos = quantidades_np * precos_np
pagtos.sum()
# Out:
# 220.0

# %% [markdown]
# Alternativamente

# %%
(quantidades_np * precos_np).sum()
# Out:
# 220.0

# %% [markdown]
# #### Acessando e mudando elementos do array

# %% [markdown]
# Algumas vezes, precisamos acessar (por qualquer motivo que seja) um sub-conjunto de um array do numpy. Pode ser que queiramos usar apenas um elemento (ex.: precisamos mandar para alguém apenas o preço do segundo item). Outras vezes, precisamos de um pedaço maior do array, em outras palavras, um sub-array.
#
# Para acessar apenas um elemento do array, podemos usar a sintaxe `a[i]`. No caso dos preços, por exemplo, podemos acessar o preço do terceiro item fazendo:

# %%
precos[2]
# Out:
# 100.75

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atenção:</b>
#
# Assim como nas listas, a contagem dos índices começa de zero. Ou seja, `0` é a posição do primeiro elemento, `1` é a posição do segundo etc.
# </div>

# %% [markdown]
# Podemos também usar números negativos para indicar os elementos do final para o início da lista (direita para esquerda); dessa forma, acessamos o último elemento com `-1`, o penúltimo com `-2` e assim por diante.

# %%
precos[-1] # equivalente a precos[len(precos)-1]
# Out:
# 2.0

# %% [markdown]
# Podemos ainda usar listas para acessar multiplos elementos de uma vez, fazendo `a[[1,2,3,4]]`. Por exemplo, se quisermos os preços dos três primeiros itens, podemos fazer:

# %%
precos_np[[0,1,2]]
# Out:
# array([ 10.5 ,  20.3 , 100.75])

# %% [markdown]
# Para acessar elementos contíguos (ou seja, adjacentes) como no caso acima, podemos também usar o que é chamado de `slicing`. Slices são escritos como `i:j` e significam algo como "acessar os itens da posição `i` (inclusa) até a posição `j` (não inclusa)". Por exemplo, para pegar os preços dos três primeiros itens, faríamos:

# %%
precos[0:3]
# Out:
# [10.5, 20.3, 100.75]

# %%
precos_np[0:3]
# Out:
# array([ 10.5 ,  20.3 , 100.75])

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Exercício:</b>
#
# Sobre o array `x`, encontre:
#
# * O décimo terceiro elemento
# * Um sub-array com o primeiro, terceiro e décimo elemento
# * Um sub-array com os 5 primeiros elementos
# * Um sub-array com os 3 últimos elementos
# </div>

# %%
x = np.random.randint(0, 100, size=30)

# %%
x
# Out:
# array([35, 36, 63, 40, 71, 53, 82, 74, 33, 92, 91, 93, 61, 56, 98, 54, 12,
#        46,  0, 53, 11, 83, 47, 79, 58, 75, 28, 31, 25, 82])

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Solução:</b>
# </div>

# %%
x[12]
# Out:
# 61

# %%
x[[0, 2, 9]]
# Out:
# array([35, 63, 92])

# %%
x[0:5]
# Out:
# array([35, 36, 63, 40, 71])

# %%
x[-3:]
# Out:
# array([31, 25, 82])

# %% [markdown]
# #### Máscaras
#
# Para acessar elementos de um array, também podemos usar uma lista de Booleanos (`True` ou `False`) do mesmo tamanho do array. Esta lista é chamada de máscara.
#
# A máscara representa quais elementos você quer preservar (representado por `True`) e quais você quer descartar (`False`) do seu resultado final. Por exemplo, para acessar os preços do primeiro e do terceiro item, fazemos:

# %%
precos_np[[True, False, True, False, False]]
# Out:
# array([ 10.5 , 100.75])

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atenção:</b>
#
# Você também pode usar um np.array de booleanos se desejar. Usamos a lista por simplicidade.
# </div>

# %% [markdown]
# O método da máscara pode parecer inútil, mas é muito útil quando você quer filtrar elementos de um array. Por exemplo, imagine que queremos somente os preços maiores que 10:

# %%
mascara = precos_np > 10

# %%
# A máscara é um np.array de booleanos
mascara
# Out:
# array([ True,  True,  True, False, False])

# %%
# Usamos então a máscara para acessar os elementos que queremos
precos_np[mascara]
# Out:
# array([ 10.5 ,  20.3 , 100.75])

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Exercício:</b>
#
# Alguns produtos tiveram mais de uma unidade pedida pelo usuário. Encontre os preços desse produtos.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Solução:</b>
# </div>

# %%
mascara = quantidades_np > 1
precos_np[mascara]
# Out:
# array([20.3,  0.5,  2. ])

# %% [markdown]
# #### Alterando elementos do array

# %% [markdown]
# Se você precisar, pode alterar elementos de um array. Para fazer isso é muito simples, para mudar o preço do terceiro para 90, fazemos:

# %%
precos[2] = 90

# %%
precos
# Out:
# [10.5, 20.3, 90, 0.5, 2.0]

# %% [markdown]
# Mais do que isso, você pode alterar multiplos elementos de uma vez! Imagine que você queira dar um desconto de 50% nos três primeiros itens da lista. Basta fazer:

# %%
precos_np[0:3] = precos_np[0:3] / 2

# %%
precos_np
# Out:
# array([ 5.25 , 10.15 , 50.375,  0.5  ,  2.   ])

# %% [markdown]
# Se você não tiver uma cópia dos dados originais guardada em algum outro local, você pode preferir criar uma cópia dessa lista de precos para depois alterar os valores na cópia e, assim, não perder os dados originais. Para isso, é necessário utilizar a função `copy`:

# %%
precos_np = np.array([10.5, 20.3, 100.75, 0.5, 2.0])

# %%
precos_np_promocao = precos_np.copy()
precos_np_promocao[0:3] = precos_np_promocao[0:3] / 2

# %%
precos_np
# Out:
# array([ 10.5 ,  20.3 , 100.75,   0.5 ,   2.  ])

# %%
precos_np_promocao
# Out:
# array([ 5.25 , 10.15 , 50.375,  0.5  ,  2.   ])

# %% [markdown]
# #### Numpy Arrays de multiplas dimensões

# %% [markdown]
# ![title](images/arrays.png)

# %% [markdown]
# Numpy dá ferramentas excelentes para a manipulação de vetores (no sentido matemático). No entanto, também é ideal quando lidamos com dados de dimensionalidade mais alta, como matrizes ou arrays em 3D. Matrizes, por serem bidimensionais (altura e largura), são capazer de representar objetos como rotações e imagens preto e branco. Arrays 3D podem ser usados para representar imagens coloridas (onde a terceira dimensão é a cor), ou um vídeo (onde a terceira dimensão é o tempo).

# %% [markdown]
# Para criar uma matriz, basta fazer:

# %%
m1 = np.array([[1,2,3], [4,5,6]])

# %%
m1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# Podemos também criar uma matriz aleatória, fazendo:

# %%
m2 = np.random.randint(0, 10, size=(3, 2))

# %%
m2
# Out:
# array([[1, 1],
#        [8, 3],
#        [2, 3]])

# %% [markdown]
# Como são matrizes, podemos fazer operações entre elas, como por exemplo a multiplicação matricial:

# %%
np.dot(m1, m2)
# Out:
# array([[23, 16],
#        [56, 37]])

# %% [markdown]
# Você também consegue transpor uma matriz, fazendo simplesmente:

# %%
m1.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %% [markdown]
# Incrível! Diversas operação estão disponíveis no `numpy` e também em outras bibliotecas como `scipy`.

# %% [markdown]
# #### Acessando dados

# %% [markdown]
# Para acessar os dados, basta usar `matriz[linha, coluna]` onde `linha` é a posição da linha e `coluna` é a posição da coluna. Por exemplo, para acessarmos a primeira linha e segunda coluna de uma matriz, fazemos:

# %%
m1[0, 1]
# Out:
# 2

# %% [markdown]
# Técnicas para acessar dados que funcionam para arrays de 1 dimensão, também funcionam aqui. Um exemplo é usar slices:

# %%
m1[0:2, 0:2]
# Out:
# array([[1, 2],
#        [4, 5]])

# %% [markdown]
# E também máscaras. Por exemplo, podemos querer só as linhas da matriz cuja segunda coluna tem valor superior a zero:

# %%
mascara = m2[:, 1] > 0  # mascara das linhas cuja segunda coluna é superior a zero
m2[mascara, :]
# Out:
# array([[1, 1],
#        [8, 3],
#        [2, 3]])

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Exercício:</b>
#
# Crie uma matriz do numpy com números aleatórios de 0 a 100. O tamanho da matriz deve ser 100 linhas por 50 colunas. Depois, use a técnica da máscara para selecionar só as linhas da matriz cujo valor da terceira coluna seja maior do que o da primeira coluna. Quantas linhas sobraram?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Solução:</b>
# </div>

# %%
matriz = np.random.randint(0, 100, size=(100, 50))

# %%
mascara = matriz[:, 2] > matriz[:, 0]
matriz[mascara, :]
# Out:
# array([[ 4, 59, 61, ...,  7,  1, 41],
#        [49, 91, 82, ..., 95, 74, 95],
#        [ 5, 90, 61, ..., 44, 11, 14],
#        ...,
#        [ 4, 61,  7, ..., 22,  4, 61],
#        [42, 12, 66, ..., 29, 48, 72],
#        [32, 71, 42, ..., 19, 56, 97]])

# %% [markdown]
# #### Operações de agregação

# %% [markdown]
# Com numpy, você consegue agregar dados com extrema facilidade. Por exemplo, é possível calcular soma, média, desvio padrão, etc. de uma matrix por linha, or coluna ou entre todos os elementos. Essas operações facilitam muito a computação de estatisticas de seus dados.
#
# Por exemplo, muitos dos modelos de machine learning funcionam melhor se os dados estiverem normalizadas, ou seja, subtraído da sua média e divido pela variância. Isso (usualmente, dependendo da distribuição original) faz com que os dados tenham a média 0 e o desvio padrão 1.

# %% [markdown]
# ![standardization](images/standardization.jpg)

# %% [markdown]
#  Em numpy, imagine que temos uma matriz cujas linhas representam pessoas, e uma coluna representa a altura (cms) e a outra coluna o peso da pessoa (em kgs). Para normalizar as alturas e os pesos, você poderia fazer:

# %%
# Criando alturas e pesos aleatórios 
alturas_pesos = np.concatenate([np.random.randint(140, 200, size=(10,1)), np.random.randint(60, 110, size=(10, 1))], axis=1)
alturas_pesos
# Out:
# array([[164,  73],
#        [163,  81],
#        [160,  68],
#        [191,  77],
#        [182,  63],
#        [155,  90],
#        [141,  71],
#        [172, 102],
#        [141,  87],
#        [187,  67]])

# %%
# normalizando
(alturas_pesos - alturas_pesos.mean(axis=0)) / alturas_pesos.std(axis=0)
# Out:
# array([[-0.09602382, -0.4247402 ],
#        [-0.1560387 ,  0.26871319],
#        [-0.33608336, -0.85814857],
#        [ 1.52437809, -0.07801351],
#        [ 0.98424412, -1.29155694],
#        [-0.63615779,  1.04884825],
#        [-1.47636618, -0.59810355],
#        [ 0.38409527,  2.08902833],
#        [-1.47636618,  0.78880323],
#        [ 1.28431855, -0.94483024]])

# %% [markdown]
# O diagrama abaixo mostra como o parâmetro `axis` afeta o calculo da média e do desvio padrão. Mudar esse parâmetro permite você calcular a média por linha, por coluna, ou geral do seus dados.

# %% [markdown]
# ![Eixos de Agregação](images/agregacao_numpy.png)

# %% [markdown]
# ### Pandas

# %% [markdown]
# <img src="images/pandas.jpeg" width=400 align="center">

# %% [markdown]
# Pandas é uma biblioteca para Python, desenvolvida para manipular dados tabulares. Essa biblioteca pode não só substituir o excel por uma alternativa mais flexível e programático, mas também é ideal para integras dados com bibliotecas de machine learning, como Sklearn e Tensorflow, que já estão preparados para lidar com dados carregados via pandas.
#
# No Pandas, matrizes são `Dataframes` e as colunas (listas com nomes para as linhas) são chamadas de `Series`.

# %% [markdown]
# Para essa parte da aula, usaremos os dados do jogo FIFA 19. Esses dados contém informações sobre todos os jogadores presentes no jogo, de diversos clubes ao redor do mundo. Esses dados podem ser [encontrados no Kaggle](https://www.kaggle.com/karangadiya/fifa19). Apesar de lúdico, esses dados têm muitas das características de dados que encontramos normalmente como data scientists: são dados brutos de indivíduos, de onde queremos extrair informações e padrões.
#
# ![fifa](images/fifa.jpeg)
#
# Nesta aula, usaremos a biblioteca Pandas para extrair informações básicas e responder perguntas sobre nossos dados.
#
# Exemplos de uso deste dataset no futuro: *clustering* dos jogadores, previsão de sua habilidade geral (*Overall*) com base em suas estatísticas, visualização dos dados, etc. Muitas destas aplicações podem ser encontradas em [notebooks do Kaggle](https://www.kaggle.com/karangadiya/fifa19/kernels).

# %% [markdown]
# #### Baixando e Carregando dados

# %%
data = pd.read_csv("data/data.csv", index_col=0)

# %% [markdown]
# Métodos e atributos bastante comuns:

# %%
data.head() #método que mostra as N primeiras linhas; por padrão, N = 5.
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club                                     Club Logo  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png
#
#        ...       Composure Marking  StandingTackle SlidingTackle  GKDiving  \
# 0      ...            96.0    33.0            28.0          26.0       6.0
# 1      ...            95.0    28.0            31.0          23.0       7.0
# 2      ...            94.0    27.0            24.0          33.0       9.0
# 3      ...            68.0    15.0            21.0          13.0      90.0
# 4      ...            88.0    68.0            58.0          51.0      15.0
#
#    GKHandling  GKKicking GKPositioning GKReflexes Release Clause
# 0        11.0       15.0          14.0        8.0        €226.5M
# 1        11.0       15.0          14.0       11.0        €127.1M
# 2         9.0       15.0          15.0       11.0        €228.1M
# 3        85.0       87.0          88.0       94.0        €138.6M
# 4        13.0        5.0          10.0       13.0        €196.4M
#
# [5 rows x 88 columns]

# %%
data.tail() #método análogo ao .head(), que mostra as N últimas linhas.
# Out:
#            ID                Name  Age  \
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
#                    Club                                       Club Logo  \
# 18202   Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 18203    Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 18204  Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 18205   Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 18206   Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#            ...       Composure Marking  StandingTackle SlidingTackle  \
# 18202      ...            45.0    40.0            48.0          47.0
# 18203      ...            42.0    22.0            15.0          19.0
# 18204      ...            41.0    32.0            13.0          11.0
# 18205      ...            46.0    20.0            25.0          27.0
# 18206      ...            43.0    40.0            43.0          50.0
#
#        GKDiving  GKHandling  GKKicking GKPositioning GKReflexes Release Clause
# 18202      10.0        13.0        7.0           8.0        9.0          €143K
# 18203      10.0         9.0        9.0           5.0       12.0          €113K
# 18204       6.0         5.0       10.0           6.0       13.0          €165K
# 18205      14.0         6.0       14.0           8.0        9.0          €143K
# 18206      10.0        15.0        9.0          12.0        9.0          €165K
#
# [5 rows x 88 columns]

# %%
data.sample() #método análogo aos dois anterios, mas mostra N linhas aleatórias.
# Out:
#           ID          Name  Age  \
# 5761  238370  M. Pongračić   20
#
#                                                Photo Nationality  \
# 5761  https://cdn.sofifa.org/players/4/19/238370.png     Croatia
#
#                                      Flag  Overall  Potential  \
# 5761  https://cdn.sofifa.org/flags/10.png       69         82
#
#                       Club                                     Club Logo  \
# 5761  FC Red Bull Salzburg  https://cdn.sofifa.org/teams/2/light/191.png
#
#           ...       Composure Marking  StandingTackle SlidingTackle  GKDiving  \
# 5761      ...            63.0    65.0            70.0          67.0       6.0
#
#       GKHandling  GKKicking GKPositioning GKReflexes Release Clause
# 5761         6.0       14.0           8.0        5.0          €3.8M
#
# [1 rows x 88 columns]

# %%
data.shape #atributo que informa a quantidade de linhas e colunas do dataframe
# Out:
# (18207, 88)

# %%
data.columns #atributo que informa os nomes das colunas do dataframe
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
data.describe() #metodo que já nos traz medidas estatísticas da distribuição das colunas
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299   1597.809908
# std     29965.244204      4.669943      6.908930      6.136496    272.586016
# min        16.000000     16.000000     46.000000     48.000000    731.000000
# 25%    200315.500000     21.000000     62.000000     67.000000   1457.000000
# 50%    221759.000000     25.000000     66.000000     71.000000   1635.000000
# 75%    236529.500000     28.000000     71.000000     75.000000   1787.000000
# max    246620.000000     45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# std                    0.394031      0.660456      0.756164      15.947765
# min                    1.000000      1.000000      1.000000       1.000000
# 25%                    1.000000      3.000000      2.000000       8.000000
# 50%                    1.000000      3.000000      2.000000      17.000000
# 75%                    1.000000      3.000000      3.000000      26.000000
# max                    5.000000      5.000000      5.000000      99.000000
#
#            Crossing      ...          Penalties     Composure       Marking  \
# count  18159.000000      ...       18159.000000  18159.000000  18159.000000
# mean      49.734181      ...          48.548598     58.648274     47.281623
# std       18.364524      ...          15.704053     11.436133     19.904397
# min        5.000000      ...           5.000000      3.000000      3.000000
# 25%       38.000000      ...          39.000000     51.000000     30.000000
# 50%       54.000000      ...          49.000000     60.000000     53.000000
# 75%       64.000000      ...          60.000000     67.000000     64.000000
# max       93.000000      ...          92.000000     96.000000     94.000000
#
#        StandingTackle  SlidingTackle      GKDiving    GKHandling  \
# count    18159.000000   18159.000000  18159.000000  18159.000000
# mean        47.697836      45.661435     16.616223     16.391596
# std         21.664004      21.289135     17.695349     16.906900
# min          2.000000       3.000000      1.000000      1.000000
# 25%         27.000000      24.000000      8.000000      8.000000
# 50%         55.000000      52.000000     11.000000     11.000000
# 75%         66.000000      64.000000     14.000000     14.000000
# max         93.000000      91.000000     90.000000     92.000000
#
#           GKKicking  GKPositioning    GKReflexes
# count  18159.000000   18159.000000  18159.000000
# mean      16.232061      16.388898     16.710887
# std       16.502864      17.034669     17.955119
# min        1.000000       1.000000      1.000000
# 25%        8.000000       8.000000      8.000000
# 50%       11.000000      11.000000     11.000000
# 75%       14.000000      14.000000     14.000000
# max       91.000000      90.000000     94.000000
#
# [8 rows x 43 columns]

# %%
data.info() #método que informa a quantidade de dados não nulos e o tipo do dado para cada coluna
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18207 entries, 0 to 18206
# Data columns (total 88 columns):
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# Skill Moves                 18159 non-null float64
# Work Rate                   18159 non-null object
# Body Type                   18159 non-null object
# Real Face                   18159 non-null object
# Position                    18147 non-null object
# Jersey Number               18147 non-null float64
# Joined                      16654 non-null object
# Loaned From                 1264 non-null object
# Contract Valid Until        17918 non-null object
# Height                      18159 non-null object
# Weight                      18159 non-null object
# LS                          16122 non-null object
# ST                          16122 non-null object
# RS                          16122 non-null object
# LW                          16122 non-null object
# LF                          16122 non-null object
# CF                          16122 non-null object
# RF                          16122 non-null object
# RW                          16122 non-null object
# LAM                         16122 non-null object
# CAM                         16122 non-null object
# RAM                         16122 non-null object
# LM                          16122 non-null object
# LCM                         16122 non-null object
# CM                          16122 non-null object
# RCM                         16122 non-null object
# RM                          16122 non-null object
# LWB                         16122 non-null object
# LDM                         16122 non-null object
# CDM                         16122 non-null object
# RDM                         16122 non-null object
# RWB                         16122 non-null object
# LB                          16122 non-null object
# LCB                         16122 non-null object
# CB                          16122 non-null object
# RCB                         16122 non-null object
# RB                          16122 non-null object
# Crossing                    18159 non-null float64
# Finishing                   18159 non-null float64
# HeadingAccuracy             18159 non-null float64
# ShortPassing                18159 non-null float64
# Volleys                     18159 non-null float64
# Dribbling                   18159 non-null float64
# Curve                       18159 non-null float64
# FKAccuracy                  18159 non-null float64
# LongPassing                 18159 non-null float64
# BallControl                 18159 non-null float64
# Acceleration                18159 non-null float64
# SprintSpeed                 18159 non-null float64
# Agility                     18159 non-null float64
# Reactions                   18159 non-null float64
# Balance                     18159 non-null float64
# ShotPower                   18159 non-null float64
# Jumping                     18159 non-null float64
# Stamina                     18159 non-null float64
# Strength                    18159 non-null float64
# LongShots                   18159 non-null float64
# Aggression                  18159 non-null float64
# Interceptions               18159 non-null float64
# Positioning                 18159 non-null float64
# Vision                      18159 non-null float64
# Penalties                   18159 non-null float64
# Composure                   18159 non-null float64
# Marking                     18159 non-null float64
# StandingTackle              18159 non-null float64
# SlidingTackle               18159 non-null float64
# GKDiving                    18159 non-null float64
# GKHandling                  18159 non-null float64
# GKKicking                   18159 non-null float64
# GKPositioning               18159 non-null float64
# GKReflexes                  18159 non-null float64
# Release Clause              16643 non-null object
# dtypes: float64(38), int64(5), object(45)
# memory usage: 12.4+ MB

# %% [markdown]
# #### Acessando dados de uma tabela

# %% [markdown]
# Você consegue acessar uma coluna inteira da tabela usando `df.nomeDaColuna`

# %%
data.Name
# Out:
# 0                    L. Messi
# 1           Cristiano Ronaldo
# 2                   Neymar Jr
# 3                      De Gea
# 4                K. De Bruyne
# 5                   E. Hazard
# 6                   L. Modrić
# 7                   L. Suárez
# 8                Sergio Ramos
# 9                    J. Oblak
# 10             R. Lewandowski
# 11                   T. Kroos
# 12                   D. Godín
# 13                David Silva
# 14                   N. Kanté
# 15                  P. Dybala
# 16                    H. Kane
# 17               A. Griezmann
# 18              M. ter Stegen
# 19                T. Courtois
# 20            Sergio Busquets
# 21                  E. Cavani
# 22                   M. Neuer
# 23                  S. Agüero
# 24               G. Chiellini
# 25                  K. Mbappé
# 26                   M. Salah
# 27                   Casemiro
# 28               J. Rodríguez
# 29                 L. Insigne
#                  ...
# 18177               R. Roache
# 18178            L. Wahlstedt
# 18179             J. Williams
# 18180                M. Hurst
# 18181                C. Maher
# 18182                 Y. Góez
# 18183           K. Pilkington
# 18184               D. Horton
# 18185                E. Tweed
# 18186            Zhang Yufeng
# 18187               C. Ehlich
# 18188              L. Collins
# 18189              A. Kaltner
# 18190              L. Watkins
# 18191    J. Norville-Williams
# 18192               S. Squire
# 18193              N. Fuentes
# 18194                J. Milli
# 18195              S. Griffin
# 18196             K. Fujikawa
# 18197              D. Holland
# 18198              J. Livesey
# 18199            M. Baldisimo
# 18200                J. Young
# 18201                D. Walsh
# 18202            J. Lundstram
# 18203      N. Christoffersson
# 18204               B. Worman
# 18205          D. Walker-Rice
# 18206               G. Nugent
# Name: Name, Length: 18207, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atenção:</b>
#
# Dessa maneira não é possível acessar colunas cujos nomes contém espaços. Nesses casos, prefira o método `.loc`.
#
# Omitindo o .loc, também conseguimos acessar as colunas utilizando colchetes e aspas (data["Nome"]).
# </div>

# %% [markdown]
# Além de usar o método acima de acessar, existem outras duas maneiras de acessar dados em pandas: uma usando o método `loc` (mais comum) e outra usando o método `iloc`. Em ambos os casos é possível acessar
#
# * Um elemento da tabela (em geral um `int`, `float` ou `str`)
# * Uma coluna (que em pandas é do tipo `pd.Series`)
# * Uma sub-tabela (que também é do tipo `pd.DataFrame`, assim como a tabela original)

# %% [markdown]
# ##### .iloc

# %% [markdown]
# O método mais simples é o `iloc`, que deixa você acessar os elementos da tabela usando os números das posições das colunas e das linhas. Isso é chamado de **acesso posicional**. Você sempre usa esse método como `df.iloc[linhas, colunas]`, onde `linhas` e `colunas` podem ser:
#
# * Inteiros, ex. 5.
# * Uma lista de inteiros, ex. `[4, 3, 0]`.
# * Um objeto slice com inteiros, ex. `1:7`.
# * Um array de booleanos, ex `[false, true, false]`.
#
# Por exemplo, se você quiser acessar a linha 0 e a coluna 1, você faz:

# %%
data.iloc[0, 1]
# Out:
# 'L. Messi'

# %% [markdown]
# Agora, usando listas de inteiros, é possível acessar a linha 0 e 1, e as colunas 1 e 2:

# %%
data.iloc[[0, 1], [1, 2]]
# Out:
#                 Name  Age
# 0           L. Messi   31
# 1  Cristiano Ronaldo   33

# %% [markdown]
# É possível selecionar multiplas linhas e colunas com `slices` usando ranges como `n:m` ao invés de números

# %%
data.iloc[0:5, 0:3]
# Out:
#        ID               Name  Age
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27

# %% [markdown]
# Podemos misturar também!

# %%
data.iloc[0:10, 1]
# Out:
# 0             L. Messi
# 1    Cristiano Ronaldo
# 2            Neymar Jr
# 3               De Gea
# 4         K. De Bruyne
# 5            E. Hazard
# 6            L. Modrić
# 7            L. Suárez
# 8         Sergio Ramos
# 9             J. Oblak
# Name: Name, dtype: object

# %% [markdown]
# ##### .loc

# %% [markdown]
# Também é possível acessar dados partir dos `nomes de linhas e de colunas`, usando o método `loc`. Esse método usa os índices das linhas (que são basicamente os "nomes" das linhas, e os nomes das colunas como forma de acessar os dados da tabela. Esse método é usado como `df.loc[linhas, colunas]`, onde `linhas` e `colunas` podem ser:
#
# * Um label único, como por exemplo `5` ou `'a'`, (note que 5 é interpretado como nome do índice nesse caso, e não como sua posição).
# * Uma lista de labels, ex `['a', 'b', 'c']`.
# * Um objeto slice com labels como `'a':'f'`.
# * Um array de booleanos, ex `[false, true, false]`.

# %%
data.loc[1, "Name"]
# Out:
# 'Cristiano Ronaldo'

# %% [markdown]
# Também é possível usar listas de nomes que você quer acessar:

# %%
data.loc[[0,1,3], ["Name", "Age"]]
# Out:
#                 Name  Age
# 0           L. Messi   31
# 1  Cristiano Ronaldo   33
# 3             De Gea   27

# %% [markdown]
# Além de aceitar usar slicing

# %%
data.loc[0:5, "ID":"Age"]
# Out:
#        ID               Name  Age
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
# 5  183277          E. Hazard   27

# %% [markdown]
# E também conseguir misturar:

# %%
data.loc[0:10, ["Name", "Age"]]
# Out:
#                  Name  Age
# 0            L. Messi   31
# 1   Cristiano Ronaldo   33
# 2           Neymar Jr   26
# 3              De Gea   27
# 4        K. De Bruyne   27
# 5           E. Hazard   27
# 6           L. Modrić   32
# 7           L. Suárez   31
# 8        Sergio Ramos   32
# 9            J. Oblak   25
# 10     R. Lewandowski   29

# %% [markdown]
# #### Acesso com array de booleanos

# %% [markdown]
# Tanto no caso de `iloc` como de `loc` é possível passar um array de booleanos. Funciona assim, cada booleano, `True` ou `False`, indica se você quer ou não, manter aquela linha/coluna na sua tabela. Por exemplo, se queremos apenas a segunda e a terceira linha da tabela podemos acessar usando um array de booleanos fazendo:
#
# `df.loc[[False, True, True, False, False, False, False, ..., False], :]`
#
# Pode não parecer muito útil a princípio (afinal, poderíamos fazer simplesmente `df.loc[[1,2], :]`, não é mesmo?) mas esta é a principal forma de filtrar dados de uma tabela, como veremos mais pra frente.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Exercício:</b>
#
# Extraia da tabela o nome e a posição dos dez últimos jogadores da tabela.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Solução:</b>
# </div>

# %%
# usando 'iloc'
data.iloc[-10:, [1, 20]]
# Out:
#                      Name Position
# 18197          D. Holland       CM
# 18198          J. Livesey       GK
# 18199        M. Baldisimo       CM
# 18200            J. Young       ST
# 18201            D. Walsh       RB
# 18202        J. Lundstram       CM
# 18203  N. Christoffersson       ST
# 18204           B. Worman       ST
# 18205      D. Walker-Rice       RW
# 18206           G. Nugent       CM

# %%
# usando 'loc'
data.loc[18196:, ["Name", "Position"]]
# ou, para não precisar colocar o número exato da linha:
# data.loc[data.shape[0]-10:, ["Name", "Position"]]
# Out:
#                      Name Position
# 18196         K. Fujikawa       CM
# 18197          D. Holland       CM
# 18198          J. Livesey       GK
# 18199        M. Baldisimo       CM
# 18200            J. Young       ST
# 18201            D. Walsh       RB
# 18202        J. Lundstram       CM
# 18203  N. Christoffersson       ST
# 18204           B. Worman       ST
# 18205      D. Walker-Rice       RW
# 18206           G. Nugent       CM

# %% [markdown]
# #### Operações lógicas e filtrando dados de uma tabela

# %% [markdown]
# Você pode fazer operações lógicas com elementos de uma dataframe. Suponha que vocês queiram ver quais jogadores tem mais de 27 anos:

# %%
data.Age >= 28
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
# 5        False
# 6         True
# 7         True
# 8         True
# 9        False
# 10        True
# 11        True
# 12        True
# 13        True
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 18177    False
# 18178    False
# 18179    False
# 18180    False
# 18181    False
# 18182    False
# 18183     True
# 18184    False
# 18185    False
# 18186    False
# 18187    False
# 18188    False
# 18189    False
# 18190    False
# 18191    False
# 18192    False
# 18193    False
# 18194    False
# 18195    False
# 18196    False
# 18197    False
# 18198    False
# 18199    False
# 18200    False
# 18201    False
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Age, Length: 18207, dtype: bool

# %% [markdown]
# Você pode usar operações como `>`, `>=`, `==` para fazer esse tipo de comparação:

# %%
data.Club == "FC Barcelona"
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7         True
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18        True
# 19       False
# 20        True
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 18177    False
# 18178    False
# 18179    False
# 18180    False
# 18181    False
# 18182    False
# 18183    False
# 18184    False
# 18185    False
# 18186    False
# 18187    False
# 18188    False
# 18189    False
# 18190    False
# 18191    False
# 18192    False
# 18193    False
# 18194    False
# 18195    False
# 18196    False
# 18197    False
# 18198    False
# 18199    False
# 18200    False
# 18201    False
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Club, Length: 18207, dtype: bool

# %% [markdown]
# Se você quiser saber quais jogadores são do Barcelona **E** têm mais de 28 anos, pode usar o operador `&` (que é basicamente um `and`, assim como `|` é um `or`):

# %%
(data.Age >= 28) & (data.Club == "FC Barcelona")
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7         True
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20        True
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 18177    False
# 18178    False
# 18179    False
# 18180    False
# 18181    False
# 18182    False
# 18183    False
# 18184    False
# 18185    False
# 18186    False
# 18187    False
# 18188    False
# 18189    False
# 18190    False
# 18191    False
# 18192    False
# 18193    False
# 18194    False
# 18195    False
# 18196    False
# 18197    False
# 18198    False
# 18199    False
# 18200    False
# 18201    False
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Length: 18207, dtype: bool

# %% [markdown]
# Podemos agora usar esses arrays  booleanos para **filtrar nossos dados**, usando `.loc` ou `.iloc`. Se quisermos filtrar a tabela e só manter as linhas dos jogadores do Barcelona, fazemos

# %%
data.loc[data.Club == "FC Barcelona", :]  # note que usamos array de booleanos para as linhas e slice para as colunas
# Out:
#            ID             Name  Age  \
# 0      158023         L. Messi   31
# 7      176580        L. Suárez   31
# 18     192448    M. ter Stegen   26
# 20     189511  Sergio Busquets   29
# 32     189242         Coutinho   26
# 42     205600        S. Umtiti   24
# 49     189332       Jordi Alba   29
# 53     168651       I. Rakitić   30
# 54     152729            Piqué   31
# 96     181872         A. Vidal   31
# 155    231443       O. Dembélé   21
# 192    199564    Sergi Roberto   26
# 228    230658           Arthur   21
# 236    222737           Malcom   21
# 239    220440       C. Lenglet   23
# 263    201400          Rafinha   25
# 266    199987     J. Cillessen   29
# 324    227928    Nélson Semedo   24
# 613    205192     Denis Suárez   24
# 1007   220253            Munir   22
# 1037   157304     T. Vermaelen   32
# 3118   208088     Sergi Samper   23
# 3684   233113            Aleñá   20
# 6000   237156         M. Wagué   19
# 6102   242816       Riqui Puig   18
# 8284   239249   Oriol Busquets   19
# 8289   239250        Abel Ruiz   18
# 8857   240915          Miranda   18
# 10526  241810            Chumi   19
# 10777  237522     Jorge Cuenca   18
# 11300  246599    Guillem Jaime   19
# 12502  225395          Ezkieta   21
# 14286  246139       Iñaki Peña   19
#
#                                                 Photo  Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png    Argentina
# 7      https://cdn.sofifa.org/players/4/19/176580.png      Uruguay
# 18     https://cdn.sofifa.org/players/4/19/192448.png      Germany
# 20     https://cdn.sofifa.org/players/4/19/189511.png        Spain
# 32     https://cdn.sofifa.org/players/4/19/189242.png       Brazil
# 42     https://cdn.sofifa.org/players/4/19/205600.png       France
# 49     https://cdn.sofifa.org/players/4/19/189332.png        Spain
# 53     https://cdn.sofifa.org/players/4/19/168651.png      Croatia
# 54     https://cdn.sofifa.org/players/4/19/152729.png        Spain
# 96     https://cdn.sofifa.org/players/4/19/181872.png        Chile
# 155    https://cdn.sofifa.org/players/4/19/231443.png       France
# 192    https://cdn.sofifa.org/players/4/19/199564.png        Spain
# 228    https://cdn.sofifa.org/players/4/19/230658.png       Brazil
# 236    https://cdn.sofifa.org/players/4/19/222737.png       Brazil
# 239    https://cdn.sofifa.org/players/4/19/220440.png       France
# 263    https://cdn.sofifa.org/players/4/19/201400.png       Brazil
# 266    https://cdn.sofifa.org/players/4/19/199987.png  Netherlands
# 324    https://cdn.sofifa.org/players/4/19/227928.png     Portugal
# 613    https://cdn.sofifa.org/players/4/19/205192.png        Spain
# 1007   https://cdn.sofifa.org/players/4/19/220253.png        Spain
# 1037   https://cdn.sofifa.org/players/4/19/157304.png      Belgium
# 3118   https://cdn.sofifa.org/players/4/19/208088.png        Spain
# 3684   https://cdn.sofifa.org/players/4/19/233113.png        Spain
#
#                                           Club Logo      ...       Composure  \
# 0      https://cdn.sofifa.org/teams/2/light/241.png      ...            96.0
# 7      https://cdn.sofifa.org/teams/2/light/241.png      ...            85.0
# 18     https://cdn.sofifa.org/teams/2/light/241.png      ...            69.0
# 20     https://cdn.sofifa.org/teams/2/light/241.png      ...            90.0
# 32     https://cdn.sofifa.org/teams/2/light/241.png      ...            85.0
# 42     https://cdn.sofifa.org/teams/2/light/241.png      ...            82.0
# 49     https://cdn.sofifa.org/teams/2/light/241.png      ...            79.0
# 53     https://cdn.sofifa.org/teams/2/light/241.png      ...            81.0
# 54     https://cdn.sofifa.org/teams/2/light/241.png      ...            86.0
# 96     https://cdn.sofifa.org/teams/2/light/241.png      ...            81.0
# 155    https://cdn.sofifa.org/teams/2/light/241.png      ...            75.0
# 192    https://cdn.sofifa.org/teams/2/light/241.png      ...            76.0
# 228    https://cdn.sofifa.org/teams/2/light/241.png      ...            84.0
# 236    https://cdn.sofifa.org/teams/2/light/241.png      ...            78.0
# 239    https://cdn.sofifa.org/teams/2/light/241.png      ...            74.0
# 263    https://cdn.sofifa.org/teams/2/light/241.png      ...            80.0
# 266    https://cdn.sofifa.org/teams/2/light/241.png      ...            61.0
# 324    https://cdn.sofifa.org/teams/2/light/241.png      ...            75.0
# 613    https://cdn.sofifa.org/teams/2/light/241.png      ...            70.0
# 1007   https://cdn.sofifa.org/teams/2/light/241.png      ...            76.0
# 1037   https://cdn.sofifa.org/teams/2/light/241.png      ...            72.0
# 3118   https://cdn.sofifa.org/teams/2/light/241.png      ...            75.0
# 3684   https://cdn.sofifa.org/teams/2/light/241.png      ...            70.0
# 6000   https://cdn.sofifa.org/teams/2/light/241.png      ...            66.0
# 6102   https://cdn.sofifa.org/teams/2/light/241.png      ...            70.0
# 8284   https://cdn.sofifa.org/teams/2/light/241.png      ...            70.0
# 8289   https://cdn.sofifa.org/teams/2/light/241.png      ...            57.0
# 8857   https://cdn.sofifa.org/teams/2/light/241.png      ...            59.0
# 10526  https://cdn.sofifa.org/teams/2/light/241.png      ...            62.0
# 10777  https://cdn.sofifa.org/teams/2/light/241.png      ...            57.0
# 11300  https://cdn.sofifa.org/teams/2/light/241.png      ...            66.0
# 12502  https://cdn.sofifa.org/teams/2/light/241.png      ...            33.0
# 14286  https://cdn.sofifa.org/teams/2/light/241.png      ...            38.0
#
#       Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0        33.0            28.0          26.0       6.0        11.0       15.0
# 7        62.0            45.0          38.0      27.0        25.0       31.0
# 18       25.0            13.0          10.0      87.0        85.0       88.0
# 20       90.0            86.0          80.0       5.0         8.0       13.0
# 32       55.0            54.0          47.0      12.0         7.0        9.0
# 42       90.0            89.0          86.0      15.0        10.0       14.0
# 49       72.0            84.0          85.0      13.0        15.0       13.0
# 53       72.0            74.0          70.0      14.0        11.0       12.0
# 54       91.0            86.0          84.0      10.0        11.0       14.0
# 96       82.0            87.0          86.0       4.0         2.0        4.0
# 155      42.0            30.0          33.0       6.0         6.0       14.0
# 192      75.0            83.0          83.0      14.0        16.0       11.0
# 228      65.0            76.0          70.0       6.0        13.0       13.0
# 236      21.0            28.0          17.0       8.0        14.0       15.0
# 239      85.0            82.0          81.0      10.0        10.0        9.0
# 263      68.0            74.0          66.0      11.0         6.0       15.0
# 266      18.0            12.0          11.0      80.0        83.0       75.0
# 324      75.0            78.0          79.0      16.0        12.0       10.0
# 613      69.0            59.0          42.0      10.0        14.0       10.0
# 1007     38.0            24.0          22.0       9.0        12.0        6.0
# 1037     72.0            79.0          80.0       9.0        10.0        7.0
# 3118     75.0            71.0          62.0      12.0        10.0       13.0
# 3684     70.0            62.0          48.0      12.0         9.0       10.0
# 6000     61.0            68.0          68.0      11.0        10.0       12.0
# 6102     53.0            57.0          53.0      12.0        15.0       14.0
# 8284     64.0            63.0          61.0       9.0         6.0        5.0
# 8289     45.0            12.0          12.0       6.0        10.0       10.0
# 8857     64.0            69.0          67.0      11.0         8.0       12.0
# 10526    70.0            65.0          63.0       7.0        14.0        9.0
# 10777    62.0            66.0          63.0      10.0        12.0        5.0
# 11300    52.0            55.0          56.0       9.0        11.0       12.0
# 12502    13.0            17.0          15.0      65.0        58.0       59.0
# 14286     9.0            10.0          11.0      63.0        57.0       64.0
#
#       GKPositioning GKReflexes Release Clause
# 0              14.0        8.0        €226.5M
# 7              33.0       37.0          €164M
# 18             85.0       90.0        €123.3M
# 20              9.0       13.0        €105.6M
# 32             14.0        6.0        €147.7M
# 42             12.0       15.0        €121.1M
# 49              6.0       13.0         €77.9M
# 53              5.0        9.0         €95.3M
# 54             15.0        8.0         €69.7M
# 96              2.0        4.0         €53.3M
# 155            10.0       13.0           €90M
# 192            15.0       10.0         €56.3M
# 228            11.0       12.0         €73.1M
# 236             7.0        9.0         €70.9M
# 239            12.0        7.0         €58.5M
# 263            13.0        7.0         €62.7M
# 266            81.0       80.0         €38.3M
# 324            14.0       12.0         €42.5M
# 613             7.0        7.0         €39.4M
# 1007           13.0       16.0         €28.1M
# 1037           11.0       15.0         €10.3M
# 3118           11.0        6.0         €10.8M
# 3684            8.0       12.0         €16.1M
# 6000           15.0       15.0          €3.6M
# 6102           12.0        9.0          €6.5M
# 8284           10.0       12.0            €4M
# 8289           10.0        8.0          €4.2M
# 8857            9.0        6.0          €3.2M
# 10526          11.0       14.0          €2.8M
# 10777          14.0       12.0          €2.3M
# 11300          10.0        6.0          €2.6M
# 12502          59.0       64.0          €1.2M
# 14286          57.0       62.0          €1.2M
#
# [33 rows x 88 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Exercício:</b>
#
# Filtre a tabela, mantendo somente os jogadores do barcelona **E** de nacionalidade espanhola.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Solução:</b>
# </div>

# %%
data.loc[(data.Club == "FC Barcelona") & (data.Nationality == "Spain"), :]
# Out:
#            ID             Name  Age  \
# 20     189511  Sergio Busquets   29
# 49     189332       Jordi Alba   29
# 54     152729            Piqué   31
# 192    199564    Sergi Roberto   26
# 613    205192     Denis Suárez   24
# 1007   220253            Munir   22
# 3118   208088     Sergi Samper   23
# 3684   233113            Aleñá   20
# 6102   242816       Riqui Puig   18
# 8284   239249   Oriol Busquets   19
# 8289   239250        Abel Ruiz   18
# 8857   240915          Miranda   18
# 10526  241810            Chumi   19
# 10777  237522     Jorge Cuenca   18
# 11300  246599    Guillem Jaime   19
# 12502  225395          Ezkieta   21
# 14286  246139       Iñaki Peña   19
#
#                                                 Photo Nationality  \
://cdn.sofifa.org/teams/2/light/241.png      ...            70.0
# 8289   https://cdn.sofifa.org/teams/2/light/241.png      ...            57.0
# 8857   https://cdn.sofifa.org/teams/2/light/241.png      ...            59.0
# 10526  https://cdn.sofifa.org/teams/2/light/241.png      ...            62.0
# 10777  https://cdn.sofifa.org/teams/2/light/241.png      ...            57.0
# 11300  https://cdn.sofifa.org/teams/2/light/241.png      ...            66.0
# 12502  https://cdn.sofifa.org/teams/2/light/241.png      ...            33.0
# 14286  https://cdn.sofifa.org/teams/2/light/241.png      ...            38.0
#
#       Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 20       90.0            86.0          80.0       5.0         8.0       13.0
# 49       72.0            84.0          85.0      13.0        15.0       13.0
# 54       91.0            86.0          84.0      10.0        11.0       14.0
# 192      75.0            83.0          83.0      14.0        16.0       11.0
# 613      69.0            59.0          42.0      10.0        14.0       10.0
# 1007     38.0            24.0          22.0       9.0        12.0        6.0
# 3118     75.0            71.0          62.0      12.0        10.0       13.0
# 3684     70.0            62.0          48.0      12.0         9.0       10.0
# 6102     53.0            57.0          53.0      12.0        15.0       14.0
# 8284     64.0            63.0          61.0       9.0         6.0        5.0
# 8289     45.0            12.0          12.0       6.0        10.0       10.0
# 8857     64.0            69.0          67.0      11.0         8.0       12.0
# 10526    70.0            65.0          63.0       7.0        14.0        9.0
# 10777    62.0            66.0          63.0      10.0        12.0        5.0
# 11300    52.0            55.0          56.0       9.0        11.0       12.0
# 12502    13.0            17.0          15.0      65.0        58.0       59.0
# 14286     9.0            10.0          11.0      63.0        57.0       64.0
#
#       GKPositioning GKReflexes Release Clause
# 20              9.0       13.0        €105.6M
# 49              6.0       13.0         €77.9M
# 54             15.0        8.0         €69.7M
# 192            15.0       10.0         €56.3M
# 613             7.0        7.0         €39.4M
# 1007           13.0       16.0         €28.1M
# 3118           11.0        6.0         €10.8M
# 3684            8.0       12.0         €16.1M
# 6102           12.0        9.0          €6.5M
# 8284           10.0       12.0            €4M
# 8289           10.0        8.0          €4.2M
# 8857            9.0        6.0          €3.2M
# 10526          11.0       14.0          €2.8M
# 10777          14.0       12.0          €2.3M
# 11300          10.0        6.0          €2.6M
# 12502          59.0       64.0          €1.2M
# 14286          57.0       62.0          €1.2M
#
# [17 rows x 88 columns]

# %% [markdown]
# #### Outras operações com pandas

# %% [markdown]
# Você também pode usar métodos de soma, média, desvio padrão para colunas (ou seja, objetos do tipo `pd.Series`) do pandas. Isso é muito simples, já que você precisa apenas usar métodos como `series.sum()`. Por exemplo, qual é a média de idade dos jogadores do Fifa? Podemos responder isso fazendo:

# %%
data.Age.mean()
# Out:
# 25.122205745043114

# %% [markdown]
# Outros métodos são `.sum()`, `.min()`, `.max()`, `.stddev()`, mas diversos outros estão disponíveis na [documentação do pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html).

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Exercício:</b>
#
# Encontre a menor idade dentre os jogadores do Barcelona. Qual (ou quais) jogadores do barcelona possuem essa idade?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Solução:</b>
# </div>

# %%
age_min_barc = data.loc[data.Club == "FC Barcelona", "Age"].min()
age_min_barc
# Out:
# 18

# %%
data.loc[(data.Club == "FC Barcelona") & (data.Age == age_min_barc), :]
# Out:
#            ID          Name  Age  \
# 6102   242816    Riqui Puig   18
# 8289   239250     Abel Ruiz   18
# 8857   240915       Miranda   18
# 10777  237522  Jorge Cuenca   18
#
#                                                 Photo Nationality  \
# 6102   https://cdn.sofifa.org/players/4/19/242816.png       Spain
# 8289   https://cdn.sofifa.org/players/4/19/239250.png       Spain
# 8857   https://cdn.sofifa.org/players/4/19/240915.png       Spain
# 10777  https://cdn.sofifa.org/players/4/19/237522.png       Spain
#
#                                       Flag  Overall  Potential          Club  \
# 6102   https://cdn.sofifa.org/flags/45.png       69         89  FC Barcelona
# 8289   https://cdn.sofifa.org/flags/45.png       67         83  FC Barcelona
# 8857   https://cdn.sofifa.org/flags/45.png       66         81  FC Barcelona
# 10777  https://cdn.sofifa.org/flags/45.png       65         78  FC Barcelona
#
#                                           Club Logo      ...       Composure  \
# 6102   https://cdn.sofifa.org/teams/2/light/241.png      ...            70.0
# 8289   https://cdn.sofifa.org/teams/2/light/241.png      ...            57.0
# 8857   https://cdn.sofifa.org/teams/2/light/241.png      ...            59.0
# 10777  https://cdn.sofifa.org/teams/2/light/241.png      ...            57.0
#
#       Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 6102     53.0            57.0          53.0      12.0        15.0       14.0
# 8289     45.0            12.0          12.0       6.0        10.0       10.0
# 8857     64.0            69.0          67.0      11.0         8.0       12.0
# 10777    62.0            66.0          63.0      10.0        12.0        5.0
#
#       GKPositioning GKReflexes Release Clause
# 6102           12.0        9.0          €6.5M
# 8289           10.0        8.0          €4.2M
# 8857            9.0        6.0          €3.2M
# 10777          14.0       12.0          €2.3M
#
# [4 rows x 88 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Exercício:</b>
#
# A habilidade do jogador, de maneira geral, está contida na coluna `Overall`. Qual time possui a maior média de habilidade, Barecelona ou Real Madrid? Qual dos dois times tem o melhor jogador?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Solução:</b>
# </div>

# %%
data.loc[data.Club == "FC Barcelona", "Overall"].mean()
# Out:
# 78.03030303030303

# %%
data.loc[data.Club == "Real Madrid", "Overall"].mean()
# Out:
# 78.24242424242425

# %% [markdown]
# O 'Overall' do Real Madrid é um pouco maior, mas qual deles tem o melhor jogador?

# %%
data.loc[data.Club == "FC Barcelona", "Overall"].max()
# Out:
# 94

# %%
data.loc[data.Club == "Real Madrid", "Overall"].max()
# Out:
# 91

# %% [markdown]
# O Barcelona!

# %% [markdown]
# #### Ordenando os dados

# %% [markdown]
# Nem sempre a tabela está ordenada da maneira ideal para resolver o seu problema. Por exemplo, você pode querer ver os jogadores do FIFA ordenados por idade. Para isso, usaremos o método `.sort_values()`:

# %%
data.sort_values(by="Age")
# Out:
#            ID                Name  Age  \
# 18206  246269           G. Nugent   16
# 17743  244752           J. Olstad   16
# 13293  246594         H. Massengo   16
# 16081  241552         J. Italiano   16
# 18166  243621            N. Ayéva   16
# 17712  245470            K. Broda   16
# 17354  242240         L. D'Arrigo   16
# 13567  246419      Y. Verschaeren   16
# 16927  243646           B. Nygren   16
# 18018  243722         B. O'Gorman   16
# 17091  243269            A. Doğan   16
# 17115  245341          C. Bassett   16
# 15793  241650            J. Lahne   16
# 15746  243169         Y. Begraoui   16
# 17175  243353            B. Mumba   16
# 18003  239594        J. Imbrechts   16
# 18106  243685           J. Cleary   16
# 17177  242074            R. Gómez   16
# 17200  245171        H. Andersson   16
# 17976  243891           M. Larsen   16
# 16418  242531         J. Kitolano   16
# 17263  245485     P. Samiec-Talar   16
# 13567                RSC Anderlecht
# 16927                  IFK Göteborg
# 18018                Bray Wanderers
# 17091                   Kayserispor
# 17115               Colorado Rapids
# 15793             IF Brommapojkarna
# 15746                    AJ Auxerre
# 17175                    Sunderland
# 18003         Sporting de Charleroi
# 18106                   Bohemian FC
# 17177           Belgrano de Córdoba
# 17200                     Örebro SK
# 17976                    Esbjerg fB
# 16418                       Odds BK
# 17263                 Śląsk Wrocław
# 18124                Bray Wanderers
# 15363                     VVV-Venlo
# 12828           CF Rayo Majadahonda
# 12496        Real Sporting de Gijón
# 18162                Vejle Boldklub
# 18044                Atlético Huila
# 17921                    Shrewsbury
# 16254                     VVV-Venlo
# ...                             ...
# 1952         Club Atlético Talleres
# 5040        Estudiantes de La Plata
# 6861                 Crystal Palace
# 4062              Unión de Santa Fe
# 5101              Standard de Liège
# 7427                       Elche CF
# 14920                  Crawley Town
# 11456                 Middlesbrough
# 10356                 Lillestrøm SK
# 12453           Jaguares de Córdoba
# 864                 Montpellier HSC
# 16264                      FC Emmen
# 14129           Yokohama F. Marinos
# 17752                   Yeovil Town
# 41              Paris Saint-Germain
# 16596                     Ohod Club
# 2821                      Patronato
# 3550                   Júbilo Iwata
# 4187               Atlético Tucumán
# 9484                 Atlético Huila
# 1294                         Foggia
# 1120                            NaN
# 7225   CD Universidad de Concepción
# 15426           Peterborough United
# 4228                   ESTAC Troyes
# 12192                     Ohod Club
# 10545                Nagoya Grampus
# 18183              Cambridge United
# 17726            Accrington Stanley
# 4741                        Pachuca
#
#                                              Club Logo      ...        \
# 18206   https://cdn.sofifa.org/teams/2/light/15048.png      ...
# 17743  https://cdn.sofifa.org/teams/2/light/112199.png      ...
# 13293      https://cdn.sofifa.org/teams/2/light/69.png      ...
# 16081  https://cdn.sofifa.org/teams/2/light/111399.png      ...
# 18166     https://cdn.sofifa.org/teams/2/light/705.png      ...
# 17712    https://cdn.sofifa.org/teams/2/light/1873.png      ...
# 17354  https://cdn.sofifa.org/teams/2/light/111393.png      ...
# 13567     https://cdn.sofifa.org/teams/2/light/229.png      ...
# 16927     https://cdn.sofifa.org/teams/2/light/319.png      ...
# 18018     https://cdn.sofifa.org/teams/2/light/838.png      ...
# 17091  https://cdn.sofifa.org/teams/2/light/101020.png      ...
# 17115     https://cdn.sofifa.org/teams/2/light/694.png      ...
# 15793  https://cdn.sofifa.org/teams/2/light/111705.png      ...
# 15746      https://cdn.sofifa.org/teams/2/light/57.png      ...
# 17175     https://cdn.sofifa.org/teams/2/light/106.png      ...
# 18003     https://cdn.sofifa.org/teams/2/light/670.png      ...
# 18106     https://cdn.sofifa.org/teams/2/light/305.png      ...
# 17177  https://cdn.sofifa.org/teams/2/light/111022.png      ...
# 17200     https://cdn.sofifa.org/teams/2/light/705.png      ...
# 17976    https://cdn.sofifa.org/teams/2/light/1445.png      ...
# 16418    https://cdn.sofifa.org/teams/2/light/1456.png      ...
# 17263  https://cdn.sofifa.org/teams/2/light/111092.png      ...
# 18124     https://cdn.sofifa.org/teams/2/light/838.png      ...
# 15363  https://cdn.sofifa.org/teams/2/light/100651.png      ...
# 12828  https://cdn.sofifa.org/teams/2/light/110066.png      ...
# 12496     https://cdn.sofifa.org/teams/2/light/459.png      ...
# 18162     https://cdn.sofifa.org/teams/2/light/822.png      ...
# 18044  https://cdn.sofifa.org/teams/2/light/112528.png      ...
# 17921     https://cdn.sofifa.org/teams/2/light/127.png      ...
# 16254  https://cdn.sofifa.org/teams/2/light/100651.png      ...
# ...                                                ...      ...
# 1952   https://cdn.sofifa.org/teams/2/light/112670.png      ...
# 5040   https://cdn.sofifa.org/teams/2/light/101083.png      ...
# 6861     https://cdn.sofifa.org/teams/2/light/1799.png      ...
# 4062   https://cdn.sofifa.org/teams/2/light/111716.png      ...
# 5101      https://cdn.sofifa.org/teams/2/light/232.png      ...
# 7427      https://cdn.sofifa.org/teams/2/light/468.png      ...
# 14920  https://cdn.sofifa.org/teams/2/light/110890.png      ...
# 11456      https://cdn.sofifa.org/teams/2/light/12.png      ...
# 10356     https://cdn.sofifa.org/teams/2/light/299.png      ...
# 12453  https://cdn.sofifa.org/teams/2/light/112903.png      ...
# 864        https://cdn.sofifa.org/teams/2/light/70.png      ...
# 16264  https://cdn.sofifa.org/teams/2/light/100628.png      ...
# 14129  https://cdn.sofifa.org/teams/2/light/101151.png      ...
# 17752     https://cdn.sofifa.org/teams/2/light/346.png      ...
# 41         https://cdn.sofifa.org/teams/2/light/73.png      ...
# 16596  https://cdn.sofifa.org/teams/2/light/113219.png      ...
# 2821   https://cdn.sofifa.org/teams/2/light/110581.png      ...
# 3550   https://cdn.sofifa.org/teams/2/light/101144.png      ...
# 4187   https://cdn.sofifa.org/teams/2/light/111708.png      ...
# 9484   https://cdn.sofifa.org/teams/2/light/112528.png      ...
# 1294   https://cdn.sofifa.org/teams/2/light/110911.png      ...
# 1120               https://cdn.sofifa.org/flags/58.png      ...
# 7225   https://cdn.sofifa.org/teams/2/light/112534.png      ...
# 15426    https://cdn.sofifa.org/teams/2/light/1938.png      ...
# 4228      https://cdn.sofifa.org/teams/2/light/294.png      ...
# 12192  https://cdn.sofifa.org/teams/2/light/113219.png      ...
# 10545  https://cdn.sofifa.org/teams/2/light/112092.png      ...
# 18183    https://cdn.sofifa.org/teams/2/light/1944.png      ...
# 17726  https://cdn.sofifa.org/teams/2/light/110313.png      ...
# 4741   https://cdn.sofifa.org/teams/2/light/110147.png      ...
#
#       Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 18206      43.0    40.0            43.0          50.0      10.0        15.0
# 17743      42.0    13.0            19.0          20.0       7.0         8.0
# 13293      50.0    52.0            62.0          65.0       8.0        14.0
# 16081      57.0    36.0            38.0          43.0       7.0         7.0
# 18166      44.0    14.0            19.0          16.0      10.0         9.0
# 17712      37.0     8.0            11.0          12.0      59.0        51.0
# 17354      41.0    20.0            35.0          34.0       5.0        10.0
# 13567      50.0    35.0            38.0          35.0      15.0         6.0
# 16927      43.0    18.0            16.0          18.0       6.0        10.0
# 18018      46.0    28.0            18.0          14.0      14.0        15.0
# 17091      41.0    52.0            67.0          58.0      14.0        14.0
# 17881   https://cdn.sofifa.org/flags/36.png       52         67
# 18206   https://cdn.sofifa.org/flags/14.png       46         66
#
#                                Club  \
# 4741                        Pachuca
# 18183              Cambridge United
# 17726            Accrington Stanley
# 10545                Nagoya Grampus
# 7225   CD Universidad de Concepción
# 1120                            NaN
# 12192                     Ohod Club
# 15426           Peterborough United
# 4228                   ESTAC Troyes
# 10356                 Lillestrøm SK
# 16264                      FC Emmen
# 9484                 Atlético Huila
# 4187               Atlético Tucumán
# 2821                      Patronato
# 3550                   Júbilo Iwata
# 1294                         Foggia
# 14129           Yokohama F. Marinos
# 41              Paris Saint-Germain
# 864                 Montpellier HSC
# 12453           Jaguares de Córdoba
# 17752                   Yeovil Town
# 16596                     Ohod Club
# 2225               SV Werder Bremen
# 1952         Club Atlético Talleres
# 4640                 Real Salt Lake
# 6861                 Crystal Palace
# 7427                       Elche CF
# 5608            Club Atlético Colón
# 4062              Unión de Santa Fe
# 10534               Kashima Antlers
# ...                             ...
# 16418                       Odds BK
# 16544                      Rochdale
# 16927                  IFK Göteborg
# 17091                   Kayserispor
# 17115               Colorado Rapids
# 17175                    Sunderland
# 17177           Belgrano de Córdoba
# 17200                     Örebro SK
# 17263                 Śląsk Wrocław
# 15793             IF Brommapojkarna
# 15746                    AJ Auxerre
# 17808               Orlando Pirates
# 18018                Bray Wanderers
# 13567                RSC Anderlecht
# 18124                Bray Wanderers
# 13293                     AS Monaco
# 18106                   Bohemian FC
# 12828           CF Rayo Majadahonda
# 18044                Atlético Huila
# 12496        Real Sporting de Gijón
# 18003         Sporting de Charleroi
# 17841                Wolfsberger AC
# 17976                    Esbjerg fB
# 11732        Toulouse Football Club
# 11457                     AS Monaco
# 17921                    Shrewsbury
# 17887                     Sydney FC
# 15363                     VVV-Venlo
# 17881                 FK Bodø/Glimt
# 18206               Tranmere Rovers
#
#                                              Club Logo      ...        \
# 4741   https://cdn.sofifa.org/teams/2/light/110147.png      ...
# 18183    https://cdn.sofifa.org/teams/2/light/1944.png      ...
# 17726  https://cdn.sofifa.org/teams/2/light/110313.png      ...
# 10545  https://cdn.sofifa.org/teams/2/light/112092.png      ...
# 7225   https://cdn.sofifa.org/teams/2/light/112534.png      ...
# 1120               https://cdn.sofifa.org/flags/58.png      ...
# 12192  https://cdn.sofifa.org/teams/2/light/113219.png      ...
# 15426    https://cdn.sofifa.org/teams/2/light/1938.png      ...
# 4228      https://cdn.sofifa.org/teams/2/light/294.png      ...
# 10356     https://cdn.sofifa.org/teams/2/light/299.png      ...
# 16264  https://cdn.sofifa.org/teams/2/light/100628.png      ...
# 9484   https://cdn.sofifa.org/teams/2/light/112528.png      ...
# 4187   https://cdn.sofifa.org/teams/2/light/111708.png      ...
# 2821   https://cdn.sofifa.org/teams/2/light/110581.png      ...
# 3550   https://cdn.sofifa.org/teams/2/light/101144.png      ...
# 1294   https://cdn.sofifa.org/teams/2/light/110911.png      ...
# 14129  https://cdn.sofifa.org/teams/2/light/101151.png      ...
# 41         https://cdn.sofifa.org/teams/2/light/73.png      ...
# 864        https://cdn.sofifa.org/teams/2/light/70.png      ...
# 12453  https://cdn.sofifa.org/teams/2/light/112903.png      ...
# 17752     https://cdn.sofifa.org/teams/2/light/346.png      ...
# 16596  https://cdn.sofifa.org/teams/2/light/113219.png      ...
# 2225       https://cdn.sofifa.org/teams/2/light/38.png      ...
# 1952   https://cdn.sofifa.org/teams/2/light/112670.png      ...
# 4640   https://cdn.sofifa.org/teams/2/light/111065.png      ...
# 6861     https://cdn.sofifa.org/teams/2/light/1799.png      ...
# 7427      https://cdn.sofifa.org/teams/2/light/468.png      ...
# 5608   https://cdn.sofifa.org/teams/2/light/110406.png      ...
# 4062   https://cdn.sofifa.org/teams/2/light/111716.png      ...
# 10534  https://cdn.sofifa.org/teams/2/light/101147.png      ...
# ...                                                ...      ...
# 16418    https://cdn.sofifa.org/teams/2/light/1456.png      ...
# 16544    https://cdn.sofifa.org/teams/2/light/1955.png      ...
# 16927     https://cdn.sofifa.org/teams/2/light/319.png      ...
# 17091  https://cdn.sofifa.org/teams/2/light/101020.png      ...
# 17115     https://cdn.sofifa.org/teams/2/light/694.png      ...
# 17175     https://cdn.sofifa.org/teams/2/light/106.png      ...
# 17177  https://cdn.sofifa.org/teams/2/light/111022.png      ...
# 17200     https://cdn.sofifa.org/teams/2/light/705.png      ...
# 17263  https://cdn.sofifa.org/teams/2/light/111092.png      ...
# 15793  https://cdn.sofifa.org/teams/2/light/111705.png      ...
# 15746      https://cdn.sofifa.org/teams/2/light/57.png      ...
# 17808  https://cdn.sofifa.org/teams/2/light/110930.png      ...
# 18018     https://cdn.sofifa.org/teams/2/light/838.png      ...
# 13567     https://cdn.sofifa.org/teams/2/light/229.png      ...
# 18124     https://cdn.sofifa.org/teams/2/light/838.png      ...
# 13293      https://cdn.sofifa.org/teams/2/light/69.png      ...
# 18106     https://cdn.sofifa.org/teams/2/light/305.png      ...
# 12828  https://cdn.sofifa.org/teams/2/light/110066.png      ...
# 18044  https://cdn.sofifa.org/teams/2/light/112528.png      ...
# 12496     https://cdn.sofifa.org/teams/2/light/459.png      ...
# 18003     https://cdn.sofifa.org/teams/2/light/670.png      ...
# 17841  https://cdn.sofifa.org/teams/2/light/111822.png      ...
# 17976    https://cdn.sofifa.org/teams/2/light/1445.png      ...
# 11732    https://cdn.sofifa.org/teams/2/light/1809.png      ...
# 11457      https://cdn.sofifa.org/teams/2/light/69.png      ...
# 17921     https://cdn.sofifa.org/teams/2/light/127.png      ...
# 17887  https://cdn.sofifa.org/teams/2/light/111400.png      ...
# 15363  https://cdn.sofifa.org/teams/2/light/100651.png      ...
# 17881     https://cdn.sofifa.org/teams/2/light/918.png      ...
# 18206   https://cdn.sofifa.org/teams/2/light/15048.png      ...
#
#       Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
#
# 18106   https://cdn.sofifa.org/flags/25.png       50         72
# 18124   https://cdn.sofifa.org/flags/25.png       49         67
# 18162   https://cdn.sofifa.org/flags/13.png       48         66
# 18166   https://cdn.sofifa.org/flags/46.png       48         72
# 18204   https://cdn.sofifa.org/flags/14.png       47         67
# 18206   https://cdn.sofifa.org/flags/14.png       46         66
#
#                                Club  \
# 4741                        Pachuca
# 17726            Accrington Stanley
# 18183              Cambridge United
# 10545                Nagoya Grampus
# 1120                            NaN
# 4228                   ESTAC Troyes
# 7225   CD Universidad de Concepción
# 12192                     Ohod Club
# 15426           Peterborough United
# 41              Paris Saint-Germain
# 864                 Montpellier HSC
# 1294                         Foggia
# 2821                      Patronato
# 3550                   Júbilo Iwata
# 4187               Atlético Tucumán
# 9484                 Atlético Huila
# 10356                 Lillestrøm SK
# 12453           Jaguares de Córdoba
# 14129           Yokohama F. Marinos
# 16264                      FC Emmen
# 16596                     Ohod Club
# 17752                   Yeovil Town
# 554                   Chievo Verona
# 1952         Club Atlético Talleres
# 2225               SV Werder Bremen
# 2706                       Cádiz CF
# 3128                        Livorno
# 3420                  Chievo Verona
# 3603                Colorado Rapids
# 4062              Unión de Santa Fe
# ...                             ...
# 16544                      Rochdale
# 16927                  IFK Göteborg
# 17091                   Kayserispor
# 17115               Colorado Rapids
# 17175                    Sunderland
# 17177           Belgrano de Córdoba
# 17200                     Örebro SK
# 17263                 Śląsk Wrocław
# 17354               Adelaide United
# 17712                  Wisła Kraków
# 17743               Sarpsborg 08 FF
# 17751                  Rosenborg BK
# 17753            Wellington Phoenix
# 17757                     Stevenage
# 17776      FC Admira Wacker Mödling
# 17808               Orlando Pirates
# 17841                Wolfsberger AC
# 17881                 FK Bodø/Glimt
# 17887                     Sydney FC
# 17921                    Shrewsbury
# 17976                    Esbjerg fB
# 18003         Sporting de Charleroi
# 18018                Bray Wanderers
# 18044                Atlético Huila
# 18106                   Bohemian FC
# 18124                Bray Wanderers
# 18162                Vejle Boldklub
# 18166                     Örebro SK
# 18204              Cambridge United
# 18206               Tranmere Rovers
#
#                                              Club Logo      ...        \
# 4741   https://cdn.sofifa.org/teams/2/light/110147.png      ...
# 17726  https://cdn.sofifa.org/teams/2/light/110313.png      ...
# 18183    https://cdn.sofifa.org/teams/2/light/1944.png      ...
# 10545  https://cdn.sofifa.org/teams/2/light/112092.png      ...
# 1120               https://cdn.sofifa.org/flags/58.png      ...
# 4228      https://cdn.sofifa.org/teams/2/light/294.png      ...
# 7225   https://cdn.sofifa.org/teams/2/light/112534.png      ...
# 12192  https://cdn.sofifa.org/teams/2/light/113219.png      ...
# 15426    https://cdn.sofifa.org/teams/2/light/1938.png      ...
# 41         https://cdn.sofifa.org/teams/2/light/73.png      ...
# 864        https://cdn.sofifa.org/teams/2/light/70.png      ...
# 1294   https://cdn.sofifa.org/teams/2/light/110911.png      ...
# 2821   https://cdn.sofifa.org/teams/2/light/110581.png      ...
# 3550   https://cdn.sofifa.org/teams/2/light/101144.png      ...
# 4187   https://cdn.sofifa.org/teams/2/light/111708.png      ...
# 9484   https://cdn.sofifa.org/teams/2/light/112528.png      ...
# 10356     https://cdn.sofifa.org/teams/2/light/299.png      ...
# 12453  https://cdn.sofifa.org/teams/2/light/112903.png      ...
# 14129  https://cdn.sofifa.org/teams/2/light/101151.png      ...
# 16264  https://cdn.sofifa.org/teams/2/light/100628.png      ...
# 16596  https://cdn.sofifa.org/teams/2/light/113219.png      ...
# 17752     https://cdn.sofifa.org/teams/2/light/346.png      ...
# 554       https://cdn.sofifa.org/teams/2/light/192.png      ...
# 1952   https://cdn.sofifa.org/teams/2/light/112670.png      ...
# 2225       https://cdn.sofifa.org/teams/2/light/38.png      ...
# 2706     https://cdn.sofifa.org/teams/2/light/1968.png      ...
# 3128     https://cdn.sofifa.org/teams/2/light/1844.png      ...
# 3420      https://cdn.sofifa.org/teams/2/light/192.png      ...
# 3603      https://cdn.sofifa.org/teams/2/light/694.png      ...
# 4062   https://cdn.sofifa.org/teams/2/light/111716.png      ...
# ...                                                ...      ...
# 16544    https://cdn.sofifa.org/teams/2/light/1955.png      ...
# 16927     https://cdn.sofifa.org/teams/2/light/319.png      ...
# 17091  https://cdn.sofifa.org/teams/2/light/101020.png      ...
# 17115     https://cdn.sofifa.org/teams/2/light/694.png      ...
# 17175     https://cdn.sofifa.org/teams/2/light/106.png      ...
# 17177  https://cdn.sofifa.org/teams/2/light/111022.png      ...
# 17200     https://cdn.sofifa.org/teams/2/light/705.png      ...
# 17263  https://cdn.sofifa.org/teams/2/light/111092.png      ...
# 17354  https://cdn.sofifa.org/teams/2/light/111393.png      ...
# 17712    https://cdn.sofifa.org/teams/2/light/1873.png      ...
# 17743  https://cdn.sofifa.org/teams/2/light/112199.png      ...
# 17751     https://cdn.sofifa.org/teams/2/light/298.png      ...
# 17753  https://cdn.sofifa.org/teams/2/light/111766.png      ...
# 17757     https://cdn.sofifa.org/teams/2/light/361.png      ...
# 17776  https://cdn.sofifa.org/teams/2/light/111821.png      ...
# 17808  https://cdn.sofifa.org/teams/2/light/110930.png      ...
# 17841  https://cdn.sofifa.org/teams/2/light/111822.png      ...
# 17881     https://cdn.sofifa.org/teams/2/light/918.png      ...
# 17887  https://cdn.sofifa.org/teams/2/light/111400.png      ...
# 17921     https://cdn.sofifa.org/teams/2/light/127.png      ...
# 17976    https://cdn.sofifa.org/teams/2/light/1445.png      ...
# 18003     https://cdn.sofifa.org/teams/2/light/670.png      ...
# 18018     https://cdn.sofifa.org/teams/2/light/838.png      ...
# 18044  https://cdn.sofifa.org/teams/2/light/112528.png      ...
# 18106     https://cdn.sofifa.org/teams/2/light/305.png      ...
# 18124     https://cdn.sofifa.org/teams/2/light/838.png      ...
# 18162     https://cdn.sofifa.org/teams/2/light/822.png      ...
# 18166     https://cdn.sofifa.org/teams/2/light/705.png      ...
# 18204    https://cdn.sofifa.org/teams/2/light/1944.png      ...
# 18206   https://cdn.sofifa.org/teams/2/light/15048.png      ...
#
#       Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
#
# %% [markdown]
# Em pandas, podemos manipular os dados de diversas maneiras. A operações mais comuns (como `+`, `-`, `==` etc), podem ser usadas diretamente, como qualquer outro objeto Python. No caso de uma coluna de um DataFrame, a operação é feita **termo a termo**:

# %%
data["Age"] + 10
# Out:
# 0        41
# 1        43
# 2        36
# 3        37
# 4        37
# 5        37
# 6        42
# 7        41
# 8        42
# 9        35
# 10       39
# 11       38
# 12       42
# 13       42
# 14       37
# 15       34
# 16       34
# 17       37
# 18       36
# 19       36
# 20       39
# 21       41
# 22       42
# 23       40
# 24       43
# 25       29
# 26       36
# 27       36
# 28       36
# 29       37
#          ..
# 18177    28
# 18178    28
# 18179    27
# 18180    32
# 18181    27
# 18182    28
# 18183    54
# 18184    28
# 18185    29
# 18186    30
# 18187    29
# 18188    27
# 18189    28
# 18190    28
# 18191    28
# 18192    28
# 18193    28
# 18194    28
# 18195    28
# 18196    29
# 18197    28
# 18198    28
# 18199    28
# 18200    28
# 18201    28
# 18202    29
# 18203    29
# 18204    26
# 18205    27
# 18206    26
# Name: Age, Length: 18207, dtype: int64

# %% [markdown]
# Podemos colocar os nossos resultados em colunas novas do DataFrame se desejarmos. Para fazer isso, simplesmente use um *assignment* do Python, assim:

# %%
data["Age in 10 years"] = data["Age"] + 10

# %% [markdown]
# No entanto, muitas vezes precisamos fazer uso de funções mais complicadas. Se conseguirmos fazer essa operação como uma função `f(x)` em Python, podemos aplicar essa função em cada elemento da coluna usando o método `.apply(f)`. Por exemplo:

# %%
def funcao_complicada(overall):
    return (overall / 10) * ((overall + 2) ** 2)

data.Overall.apply(funcao_complicada)
# Out:
# 0        86630.4
# 1        86630.4
# 2        81291.2
# 3        78705.9
# 4        78705.9
# 5        78705.9
# 6        78705.9
# 7        78705.9
# 8        78705.9
# 9        76176.0
# 10       76176.0
# 11       76176.0
# 12       76176.0
# 13       76176.0
# 14       73700.9
# 15       73700.9
# 16       73700.9
# 17       73700.9
# 18       73700.9
# 19       73700.9
# 20       73700.9
# 21       73700.9
# 22       73700.9
# 23       73700.9
# 24       73700.9
# 25       71280.0
# 26       71280.0
# 27       71280.0
# 28       71280.0
# 29       71280.0
#           ...
# 18177    12000.0
# 18178    12000.0
# 18179    12000.0
# 18180    12000.0
# 18181    12000.0
# 18182    12000.0
# 18183    12000.0
# 18184    12000.0
# 18185    12000.0
# 18186    11284.7
# 18187    11284.7
# 18188    11284.7
# 18189    11284.7
# 18190    11284.7
# 18191    11284.7
# 18192    11284.7
# 18193    11284.7
# 18194    11284.7
# 18195    11284.7
# 18196    11284.7
# 18197    11284.7
# 18198    11284.7
# 18199    11284.7
# 18200    11284.7
# 18201    11284.7
# 18202    11284.7
# 18203    11284.7
# 18204    11284.7
# 18205    11284.7
# 18206    10598.4
# Name: Overall, Length: 18207, dtype: float64

# %% [markdown]
# ##### Agrupando dados e tirando estatísticas

# %% [markdown]
# Muitas vezes precisamos agrupar e tirar informações de cada grupo na nossa tabela. Por exemplo, podemos querer saber a idade média por clube, o *Overall* médio por país, o número de clubes por país, o número de jogadores por país etc. Para extrair todas essas informações, precisamos agrupar os dados e tirar alguma informação de cada grupo. A biblioteca pandas facilita esse trabalho e dá maneiras simples de responder todas essas perguntas.
#
# A agregação mais simples que podemos fazer em Pandas é a *quantidade de vezes que cada elemento aparece em uma coluna*, usando o método `.value_counts()`. Por exemplo, para encontrar a quantidade de jogadores por país, fazemos:

# %%
data.Nationality.value_counts()
# Out:
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
# Brazil                   827
# Italy                    702
# Colombia                 618
# Japan                    478
# Netherlands              453
# Sweden                   397
# China PR                 392
# Chile                    391
# Republic of Ireland      368
# Mexico                   366
# United States            353
# Poland                   350
# Norway                   341
# Saudi Arabia             340
# Denmark                  336
# Korea Republic           335
# Portugal                 322
# Turkey                   303
# Austria                  298
# Scotland                 286
# Belgium                  260
# Australia                236
# Switzerland              220
# Uruguay                  149
# Senegal                  130
#                         ...
# Chad                       2
# Philippines                2
# Dominican Republic         2
# Bermuda                    2
# Eritrea                    2
# Nicaragua                  2
# Belize                     1
# Botswana                   1
# Palestine                  1
# Oman                       1
# South Sudan                1
# Mauritius                  1
# Andorra                    1
# United Arab Emirates       1
# Rwanda                     1
# São Tomé & Príncipe        1
# Malta                      1
# Ethiopia                   1
# Liberia                    1
# Kuwait                     1
# Lebanon                    1
# Fiji                       1
# Qatar                      1
# Puerto Rico                1
# St Lucia                   1
# Indonesia                  1
# Grenada                    1
# Jordan                     1
# New Caledonia              1
# Guam                       1
# Name: Nationality, Length: 164, dtype: int64

# %% [markdown]
# Para agregar estatísticas mais complicadas, precisamos usar o método `.groupby()`. Por exemplo, para encontrar a média de *Overall* por clube, fazemos assim: fazemos um grupo por cada *Club* usando `.groupby("Club")`, depois pegamos a coluna `Overall` e tiramos a a média usando `.mean()`.

# %%
data.groupby("Club").Overall.mean()
# Out:
# Club
#  SSV Jahn Regensburg        65.586207
# 1. FC Heidenheim 1846       65.750000
# 1. FC Kaiserslautern        63.384615
# 1. FC Köln                  70.785714
# 1. FC Magdeburg             65.615385
# 1. FC Nürnberg              68.827586
# 1. FC Union Berlin          68.321429
# 1. FSV Mainz 05             70.843750
# AC Ajaccio                  65.043478
# AC Horsens                  60.640000
# AD Alcorcón                 67.413793
# ADO Den Haag                66.678571
# AEK Athens                  70.214286
# AFC Wimbledon               60.461538
# AIK                         65.074074
# AJ Auxerre                  66.296296
# AS Béziers                  62.038462
# AS Monaco                   72.939394
# AS Nancy Lorraine           64.666667
# AS Saint-Étienne            70.875000
# AZ Alkmaar                  70.000000
# Aalborg BK                  62.037037
# Aarhus GF                   61.407407
# Aberdeen                    64.333333
# Accrington Stanley          61.178571
# Adelaide United             61.400000
# Ajax                        73.633333
# Akhisar Belediyespor        69.115385
# Al Ahli                     65.700000
# Al Batin                    59.833333
#                               ...
# Vitesse                     68.464286
# Vitória                     70.400000
# Vitória Guimarães           72.333333
# Vitória de Setúbal          68.892857
# Vålerenga Fotball           61.769231
# Vélez Sarsfield             65.250000
# Waasland-Beveren            64.714286
# Walsall                     63.370370
# Waterford FC                57.200000
# Watford                     72.344828
# Wellington Phoenix          62.190476
# West Bromwich Albion        69.533333
# West Ham United             73.093750
# Western Sydney Wanderers    61.840000
# Wigan Athletic              66.566667
# Willem II                   65.285714
# Wisła Kraków                62.461538
# Wisła Płock                 61.038462
# Wolfsberger AC              61.538462
# Wolverhampton Wanderers     68.818182
# Wycombe Wanderers           63.720000
# Yeni Malatyaspor            65.566667
# Yeovil Town                 60.357143
# Yokohama F. Marinos         61.533333
# Zagłębie Lubin              62.629630
# Zagłębie Sosnowiec          60.760000
# Çaykur Rizespor             66.900000
# Örebro SK                   60.481481
# Östersunds FK               63.545455
# Śląsk Wrocław               62.200000
# Name: Overall, Length: 651, dtype: float64

# %% [markdown]
# Podemos pegar tirar a média de mais uma coluna, usando `[col1, col2]` para acessá-las. Por exemplo, para tirar a média de `Age` e de `Overall` para cada `Club`, fazemos:

# %%
data.groupby("Club")["Overall", "Age"].mean()
# Out:
#                             Overall        Age
# Club
#  SSV Jahn Regensburg      65.586207  25.655172
# 1. FC Heidenheim 1846     65.750000  24.000000
# 1. FC Kaiserslautern      63.384615  23.846154
# 1. FC Köln                70.785714  24.321429
# 1. FC Magdeburg           65.615385  24.692308
# 1. FC Nürnberg            68.827586  23.793103
# 1. FC Union Berlin        68.321429  25.250000
# 1. FSV Mainz 05           70.843750  23.687500
# AC Ajaccio                65.043478  27.043478
# AC Horsens                60.640000  25.000000
# AD Alcorcón               67.413793  26.896552
# ADO Den Haag              66.678571  24.678571
# AEK Athens                70.214286  24.535714
# AFC Wimbledon             60.461538  23.615385
# AIK                       65.074074  26.074074
# AJ Auxerre                66.296296  25.185185
# AS Béziers                62.038462  25.769231
# AS Monaco                 72.939394  23.060606
# AS Nancy Lorraine         64.666667  24.933333
# AS Saint-Étienne          70.875000  25.416667
# AZ Alkmaar                70.000000  23.066667
# Aalborg BK                62.037037  23.370370
# Aarhus GF                 61.407407  23.777778
# Aberdeen                  64.333333  24.148148
# Accrington Stanley        61.178571  24.821429
# Adelaide United           61.400000  24.360000
# Ajax                      73.633333  22.300000
# Akhisar Belediyespor      69.115385  29.269231
# Al Ahli                   65.700000  25.933333
# Al Batin                  59.833333  25.100000
# ...                             ...        ...
# Vitesse                   68.464286  24.464286
# Vitória                   70.400000  30.000000
# Vitória Guimarães         72.333333  24.566667
# Vitória de Setúbal        68.892857  25.392857
# Vålerenga Fotball         61.769231  23.192308
# Vélez Sarsfield           65.250000  23.214286
# Waasland-Beveren          64.714286  22.500000
# Walsall                   63.370370  23.814815
# Waterford FC              57.200000  23.880000
# Watford                   72.344828  25.482759
# Wellington Phoenix        62.190476  25.380952
# West Bromwich Albion      69.533333  25.800000
# West Ham United           73.093750  25.437500
# Western Sydney Wanderers  61.840000  24.080000
# Wigan Athletic            66.566667  24.533333
# Willem II                 65.285714  22.678571
# Wisła Kraków              62.461538  24.500000
# Wisła Płock               61.038462  24.115385
# Wolfsberger AC            61.538462  24.615385
# Wolverhampton Wanderers   68.818182  22.848485
# Wycombe Wanderers         63.720000  27.400000
# Yeni Malatyaspor          65.566667  25.866667
# Yeovil Town               60.357143  24.250000
# Yokohama F. Marinos       61.533333  25.033333
# Zagłębie Lubin            62.629630  25.703704
# Zagłębie Sosnowiec        60.760000  26.240000
# Çaykur Rizespor           66.900000  25.433333
# Örebro SK                 60.481481  24.037037
# Östersunds FK             63.545455  23.863636
# Śląsk Wrocław             62.200000  25.960000
#
# [651 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Atenção:</b>
#
# Note que a coluna que você agrupou, nesse caso `Club`, vira o índice das linhas no resultado final.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Exercício:</b>
#
# Potencial não realizado é a diferença entre as colunas `Potential` (potencial que o jogador tem de chegar em termos de habilidade) e `Overall` (habilidade atual do jogador). Encontre o time de **maior média de potencial não realizado**.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Solução:</b>
# </div>

# %%
data["Unrealized Potential"] = data.Potential - data.Overall

# %%
data.groupby("Club")["Unrealized Potential"].mean().sort_values(ascending=False)
# Out:
# Club
# FC Nordsjælland              11.000000
# Stabæk Fotball               10.888889
# Envigado FC                  10.178571
# Derry City                   10.111111
# FC Sochaux-Montbéliard       10.000000
# Crewe Alexandra               9.464286
# LOSC Lille                    9.320000
# Bohemian FC                   9.240000
# Barnsley                      9.142857
# Bray Wanderers                8.956522
# FC Groningen                  8.807692
# Wolverhampton Wanderers       8.757576
# Sligo Rovers                  8.736842
# Hamburger SV                  8.733333
# Shamrock Rovers               8.590909
# Colchester United             8.392857
# Club Atlético Banfield        8.333333
# Vejle Boldklub                8.333333
# Atlético Huila                8.321429
# Olympique Lyonnais            8.275862
# FC Red Bull Salzburg          8.222222
# Vélez Sarsfield               8.214286
# CD Huachipato                 8.074074
# Club Atlético Talleres        8.071429
# AS Monaco                     8.000000
# FC Admira Wacker Mödling      7.925926
# Aalborg BK                    7.925926
# PFC CSKA Moscow               7.892857
# Tromsø IL                     7.850000
# Vålerenga Fotball             7.846154
#                                ...
# Viktoria Plzeň                2.375000
# Cagliari                      2.375000
# Hebei China Fortune FC        2.357143
# Jeju United FC                2.285714
# GD Chaves                     2.240000
# FC Seoul                      2.178571
# Kawasaki Frontale             2.133333
# BB Erzurumspor                2.120000
# Vegalta Sendai                2.111111
# Sangju Sangmu FC              2.035714
# Inter                         2.000000
# Urawa Red Diamonds            1.925926
# Cerezo Osaka                  1.700000
# MKE Ankaragücü                1.448276
# Akhisar Belediyespor          1.192308
# Internacional                 0.000000
# Ceará Sporting Club           0.000000
# Vitória                       0.000000
# Chapecoense                   0.000000
# América FC (Minas Gerais)     0.000000
# Cruzeiro                      0.000000
# Sport Club do Recife          0.000000
# Bahia                         0.000000
# Atlético Paranaense           0.000000
# Santos                        0.000000
# Atlético Mineiro              0.000000
# Fluminense                    0.000000
# Grêmio                        0.000000
# Paraná                        0.000000
# Botafogo                      0.000000
# Name: Unrealized Potential, Length: 651, dtype: float64

# %% [markdown]
# #### Dados ausentes ou nulos

# %% [markdown]
# Em muitos casos, os dados que um data scientist vai trabalhar não estão em perfeitas condições. Em muitos casos, várias colunas possuem, por exemplo, dados ausentes, seja por falhas no processo de capptura, por esses dados estarem indisponíveis, ou por esse dado não fazer sentido para aquele caso (por exemplo, na linha de um jogador novato, a coluna de "Clube anterior" pode estar vazia pois aquele é seu primeiro clube).
#
# Para investigar se cada elemento de uma coluna é nulo ou não, podemos usar os métodos `.isnull()` ou `.notnull()`. Por exemplo, para vez quais elementos da coluna `Club` estão nulos:

# %%
data.Club.isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 18177    False
# 18178    False
# 18179    False
# 18180    False
# 18181    False
# 18182    False
# 18183    False
# 18184    False
# 18185    False
# 18186    False
# 18187    False
# 18188    False
# 18189    False
# 18190    False
# 18191    False
# 18192    False
# 18193    False
# 18194    False
# 18195    False
# 18196    False
# 18197    False
# 18198    False
# 18199    False
# 18200    False
# 18201    False
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Club, Length: 18207, dtype: bool

# %% [markdown]
# Mas quantos deles são nulos? Para isso, basta somar todos os `True` que temos no resultado acima:

# %%
data.Club.isnull().sum()
# Out:
# 241

# %% [markdown]
# Então 241 jogadores estão sem clube! Podemos agora querer preencher esses valores nulos com a string `"No Club"`. Para fazer isso, usamos o método `.fillna()`:

# %%
data["Filled Club"] = data.Club.fillna("No Club")

# %%
data["Filled Club"].isnull().sum()
# Out:
# 0

# %% [markdown]
# Note que a coluna `Filled Club` não tem mais valores nulos.

# %% [markdown]
# Outra operação muito comum em trabalho de data science é jogar fora colunas que tem algum valor nulo. Podemos fazer isso usando o método `dropna()`, assim:

# %%
data.dropna(axis="columns")
# Out:
#            ID                  Name  Age  \
# 0      158023              L. Messi   31
# 1       20801     Cristiano Ronaldo   33
# 2      190871             Neymar Jr   26
# 3      193080                De Gea   27
# 4      192985          K. De Bruyne   27
# 5      183277             E. Hazard   27
# 6      177003             L. Modrić   32
# 7      176580             L. Suárez   31
# 8      155862          Sergio Ramos   32
# 9      200389              J. Oblak   25
# 10     188545        R. Lewandowski   29
# 11     182521              T. Kroos   28
# 12     182493              D. Godín   32
# 13     168542           David Silva   32
# 14     215914              N. Kanté   27
# 15     211110             P. Dybala   24
# 16     202126               H. Kane   24
# 17     194765          A. Griezmann   27
# 18     192448         M. ter Stegen   26
# 19     192119           T. Courtois   26
# 20     189511       Sergio Busquets   29
# 21     179813             E. Cavani   31
# 22     167495              M. Neuer   32
# 23     153079             S. Agüero   30
# 24     138956          G. Chiellini   33
# 25     231747             K. Mbappé   19
# 26     209331              M. Salah   26
# 27     200145              Casemiro   26
# 28     198710          J. Rodríguez   26
# 29     198219            L. Insigne   27
# ...       ...                   ...  ...
# 18177  238550             R. Roache   18
# 18178  243158          L. Wahlstedt   18
# 18179  246243           J. Williams   17
# 18180  221669              M. Hurst   22
# 18181  245734              C. Maher   17
# 18182  246001               Y. Góez   18
# 18183   53748         K. Pilkington   44
# 18184  241657             D. Horton   18
# 18185  243961              E. Tweed   19
# 18186  240917          Zhang Yufeng   20
# 18187  240158             C. Ehlich   19
# 18188  240927            L. Collins   17
# 18189  240160            A. Kaltner   18
# 18190  245569            L. Watkins   18
# 18191  245570  J. Norville-Williams   18
# 18192  245571             S. Squire   18
# 18193  244823            N. Fuentes   18
# 7         2346               41                     0            FC Barcelona
# 8         2201               42                     0             Real Madrid
# 9         1331               35                     3         Atlético Madrid
# 10        2152               39                     0       FC Bayern München
# 11        2190               38                     0             Real Madrid
# 12        1946               42                     0         Atlético Madrid
# 13        2115               42                     0         Manchester City
# 14        2189               37                     1                 Chelsea
# 15        2092               34                     5                Juventus
# 16        2165               34                     2       Tottenham Hotspur
# 17        2246               37                     1         Atlético Madrid
# 18        1328               36                     3            FC Barcelona
# 19        1311               36                     1             Real Madrid
# 20        2065               39                     0            FC Barcelona
# 21        2161               41                     0     Paris Saint-Germain
# 22        1473               42                     0       FC Bayern München
# 23        2107               40                     0         Manchester City
# 24        1841               43                     0                Juventus
# 25        2118               29                     7     Paris Saint-Germain
# 26        2146               36                     1               Liverpool
# 27        2170               36                     2             Real Madrid
# 28        2171               36                     1       FC Bayern München
# 29        2017               37                     0                  Napoli
# ...        ...              ...                   ...                     ...
# 18177     1178               28                    21               Blackpool
# 18178      738               28                    17              Dalkurd FF
# 18179     1166               27                    16        Northampton Town
# 18180      987               32                    10        St. Johnstone FC
# 18181     1296               27                    18          Bray Wanderers
# 18182     1311               28                    17       Atlético Nacional
# 18183      774               54                     0        Cambridge United
# 18184     1368               28                     7            Lincoln City
# 18185     1315               29                    11              Derry City
# 18186     1389               30                    17        Beijing Renhe FC
# 18187     1366               29                    12      SpVgg Unterhaching
# 18188     1297               27                    15          Newport County
# 18189     1290               28                    14      SpVgg Unterhaching
# 18190     1285               28                    20        Cambridge United
# 18191     1250               28                    18        Cambridge United
# 18192     1325               28                    17        Cambridge United
# 18193     1191               28                    17          Unión Española
# 18194      731               28                    18                   Lecce
# 18195     1325               28                    20            Waterford FC
# 18196     1333               29                    14            Júbilo Iwata
# 18197     1362               28                    14               Cork City
# 18198      792               28                    23           Burton Albion
# 18199     1303               28                    22  Vancouver Whitecaps FC
# 18200     1203               28                    15            Swindon Town
# 18201     1098               28                    21            Waterford FC
# 18202     1307               29                    18         Crewe Alexandra
# 18203     1098               29                    16          Trelleborgs FF
# 18204     1189               26                    20        Cambridge United
# 18205     1228               27                    19         Tranmere Rovers
# 18206     1321               26                    20         Tranmere Rovers
#
# [18207 rows x 15 columns]

# %% [markdown]
# Veja que só sobraram 14 colunas. Se quisermos jogar todas as linhas que tenham algum valor nulo, basta colocar o parâmetro `axis="rows"` no método `.dropna()`

# %% [markdown]
# ## Pandas ou numpy?

# %% [markdown]
# É importante saber alguns prós e contras do Numpy e Pandas para quando vamos escolher a melhor ferramenta para realizar alguma tarefa.
#
# Algumas dicas:
#
# * Dados tabulares -> preferência a Pandas
# * problema por estritamente um problema de algebra linear (como decomposição de matrizes ou manipulação de vetores) -> escolha Numpy
# * Performance: numpy é mais simples e sua simplicidade resulta em um código mais otimizado (com diversas partes internas escritas em C ao invés de Python). Se a performance das suas operações no pandas é um problema, troque para Numpy para fazer os cálculos mais pesados.
# * **Usem SEMPRE a documentação e a comunidade (como Stack Overflow), pois essas são as principais vantagens de utilizar Python e essas bibliotecas mais "famosas".**
